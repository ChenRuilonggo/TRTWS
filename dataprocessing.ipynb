# %% [markdown]
# sn-RNA seq expression files after regressing out covariates:
# Astrocytes: "/projects/YangLabData/qliu/TIGAR/input/single_cell/1st_step/Refreshed/Ast_gene_exp.tsv"
# Excitatory Neurons: "/projects/YangLabData/qliu/TIGAR/input/single_cell/1st_step/Refreshed/Ex_gene_exp.tsv"
# Inhibitory Neurons: "/projects/YangLabData/qliu/TIGAR/input/single_cell/1st_step/Refreshed/In_gene_exp.tsv"
# Microglia: "/projects/YangLabData/qliu/TIGAR/input/single_cell/1st_step/Refreshed/Mic_gene_exp.tsv"
# Oligodendrocytes: "/projects/YangLabData/qliu/TIGAR/input/single_cell/1st_step/Refreshed/Oli_gene_exp.tsv"
# Oligodendrocyte precursor cells: "/projects/YangLabData/qliu/TIGAR/input/single_cell/1st_step/Refreshed/Opc_gene_exp.tsv"
# LDetect region info: "/projects/YangLabData/qliu/cTWAS/ldetect_region.txt"

# %%
import pandas as pd

# 定义每种细胞类型及其对应的文件路径
file_paths = {
    "Astrocytes": "/projects/YangLabData/qliu/TIGAR/input/single_cell/1st_step/Refreshed/Ast_gene_exp.tsv",
    "Excitatory_Neurons": "/projects/YangLabData/qliu/TIGAR/input/single_cell/1st_step/Refreshed/Ex_gene_exp.tsv",
    "Inhibitory_Neurons": "/projects/YangLabData/qliu/TIGAR/input/single_cell/1st_step/Refreshed/In_gene_exp.tsv",
    "Microglia": "/projects/YangLabData/qliu/TIGAR/input/single_cell/1st_step/Refreshed/Mic_gene_exp.tsv",
    "Oligodendrocytes": "/projects/YangLabData/qliu/TIGAR/input/single_cell/1st_step/Refreshed/Oli_gene_exp.tsv",
    "OPCs": "/projects/YangLabData/qliu/TIGAR/input/single_cell/1st_step/Refreshed/Opc_gene_exp.tsv"
}

# 用一个字典存储每个细胞类型对应的表达矩阵
expression_data = {}

# 遍历文件并读取
for cell_type, path in file_paths.items():
    df = pd.read_csv(path, sep='\t', index_col=0)  # 一般第1列是基因名或ID，设为index
    expression_data[cell_type] = df
    print(f"{cell_type} loaded: {df.shape}")

# 现在你可以通过例如 expression_data["Astrocytes"] 来访问表达矩阵
# Out:
# Astrocytes loaded: (15917, 419)
# Excitatory_Neurons loaded: (15917, 419)
# Inhibitory_Neurons loaded: (15917, 419)
# Microglia loaded: (15917, 419)
# Oligodendrocytes loaded: (15917, 419)
# OPCs loaded: (15917, 419)

# %%
expression_data['Astrocytes'].head
# Out:
# <bound method NDFrame.head of           CHROM  GeneStart    GeneEnd         TargetID  SM-CTDQP  SM-CJEJ2  \
# GeneName
# A1BG         19   58345178   58353492  ENSG00000121410  0.035796  0.010619
# A1CF         10   50799409   50885675  ENSG00000148584  0.016691  0.087019
# A2M          12    9067664    9116229  ENSG00000175899 -0.005721  1.020452
# A2ML1        12    8822621    8887001  ENSG00000166535 -0.046901  0.089190
# A3GALT2       1   33306766   33321098  ENSG00000184389  0.008798  0.041760
# ...         ...        ...        ...              ...       ...       ...
# ZXDC          3  126437601  126475891  ENSG00000070476 -0.040732 -0.189145
# ZYG11A        1   52842511   52894998  ENSG00000203995 -0.000159 -0.027012
# ZYG11B        1   52726453   52827336  ENSG00000162378 -0.273811 -0.447721
# ZYX           7  143381295  143391111  ENSG00000159840  0.033062  0.218942
# ZZEF1        17    4004445    4143030  ENSG00000074755 -0.104621  0.053362
#
#           SM-CTDQV  SM-CJK5G  SM-CTEDG  SM-CTDTI  ...  SM-CJGGS  SM-CJIYV  \
# GeneName                                          ...
# A1BG      0.047650 -0.051371  0.208200 -0.195144  ... -0.056864 -0.112210
# A1CF     -0.010457  0.009243  0.017583 -0.048653  ...  0.001556 -0.012883
# A2M       0.040905 -0.581716  0.124343 -0.201461  ...  0.698324  0.628701
# A2ML1     0.100663  0.029157  0.061858 -0.069276  ... -0.178812 -0.044342
# A3GALT2  -0.009906 -0.029793 -0.023375  0.012681  ... -0.028174  0.016912
# ...            ...       ...       ...       ...  ...       ...       ...
# ZXDC      0.330837 -0.081989  0.706004 -0.012041  ...  0.255521 -0.245663
# ZYG11A   -0.011628  0.047612 -0.013490 -0.034539  ... -0.013171 -0.001994
# ZYG11B   -0.069871  1.494424  1.111853 -0.332087  ... -0.962092 -0.618663
# ZYX       0.567874  1.059727  1.256765 -0.012487  ... -0.393869 -0.174085
# ZZEF1     0.216269  0.436471  0.942874 -0.084396  ... -0.061896 -0.095409
#
#           SM-CJGGV  SM-CTDT7  SM-CJEJT  SM-CJGLT  SM-CTDS7  SM-CJGH9  \
# GeneName
# A1BG      0.216436  0.209585  0.260392 -0.214056 -0.181616  0.152387
# A1CF      0.003497  0.057722 -0.003236 -0.000475  0.012476 -0.007582
# A2M       0.096962 -0.236546 -0.097153 -0.296472 -0.160559 -0.057568
# A2ML1     0.106405  0.166718 -0.031840 -0.057585  0.034344  0.282695
# A3GALT2  -0.010673  0.010332  0.079289  0.007598  0.002596  0.120147
# ...            ...       ...       ...       ...       ...       ...
# ZXDC      1.020676  0.486177  0.232791 -0.609525  1.153194  1.021808
# ZYG11A    0.024479 -0.020449  0.035075 -0.020508 -0.027093  0.003181
# ZYG11B    1.459424  1.105945  0.335208 -0.191237  0.275679  0.775286
# ZYX       0.807434  1.560959  0.340582 -0.402751  0.757377  0.662313
# ZZEF1     0.764406  0.526253  0.548858 -0.600594  1.132525  1.121432
#
#           SM-CTDS5  SM-CJFME
# GeneName
# A1BG     -0.017086 -0.059043
# A1CF     -0.036490 -0.036524
# A2M       0.131800 -0.007708
# A2ML1     0.053385  0.012056
# A3GALT2  -0.018730 -0.040810
# ...            ...       ...
# ZXDC      0.622050  0.618890
# ZYG11A    0.016995  0.007824
# ZYG11B    0.448952  0.014884
# ZYX       0.571675  0.172686
# ZZEF1     0.442541 -0.003734
#
# [15917 rows x 419 columns]>

# %%
expression_data["Excitatory_Neurons"].head
# Out:
# <bound method NDFrame.head of           CHROM  GeneStart    GeneEnd         TargetID  SM-CTDQP  SM-CJEJ2  \
# GeneName
# A1BG         19   58345178   58353492  ENSG00000121410 -0.001282 -0.190665
# A1CF         10   50799409   50885675  ENSG00000148584  0.006378  0.066144
# A2M          12    9067664    9116229  ENSG00000175899 -0.015789  0.220741
# A2ML1        12    8822621    8887001  ENSG00000166535 -0.022827  0.087522
# A3GALT2       1   33306766   33321098  ENSG00000184389 -0.005277  0.018207
# ...         ...        ...        ...              ...       ...       ...
# ZXDC          3  126437601  126475891  ENSG00000070476 -0.139487 -0.631575
# ZYG11A        1   52842511   52894998  ENSG00000203995  0.002112  0.010998
# ZYG11B        1   52726453   52827336  ENSG00000162378 -0.328356 -0.885141
# ZYX           7  143381295  143391111  ENSG00000159840 -0.022257 -0.371733
# ZZEF1        17    4004445    4143030  ENSG00000074755 -0.188338 -0.269432
#
#           SM-CTDQV  SM-CJK5G  SM-CTEDG  SM-CTDTI  ...  SM-CJGGS  SM-CJIYV  \
# GeneName                                          ...
# A1BG     -0.067863  0.027293  0.064961 -0.150808  ... -0.015961 -0.038968
# A1CF     -0.008356 -0.003262  0.014632 -0.023326  ...  0.004517 -0.015709
# A2M       0.032240 -0.081329  0.032401 -0.188557  ... -0.142760 -0.249451
# A2ML1     0.093257 -0.167621  0.037625 -0.079613  ... -0.018187  0.049935
# A3GALT2  -0.009232 -0.022698 -0.014211  0.021429  ... -0.020533 -0.010982
# ...            ...       ...       ...       ...  ...       ...       ...
# ZXDC      0.072264 -0.436298  0.153630 -0.223903  ... -0.101866 -0.440580
# ZYG11A    0.004758  0.019948 -0.003491 -0.003642  ... -0.005468 -0.001191
# ZYG11B   -0.445614 -0.480655  0.495832  0.044991  ... -0.353762  0.266096
# ZYX       0.124272 -0.094934  0.487481 -0.103594  ...  0.135935  0.157998
# ZZEF1     0.090092 -0.435228  0.348349 -0.041638  ...  0.263651 -0.258189
#
#           SM-CJGGV  SM-CTDT7  SM-CJEJT  SM-CJGLT  SM-CTDS7  SM-CJGH9  \
# GeneName
# A1BG      0.129279 -0.033722  0.182979 -0.114899 -0.485648  0.048498
# A1CF      0.012488  0.023539  0.010684  0.007072 -0.040026 -0.015539
# A2M       0.124332 -0.201475  0.135067 -0.015930 -0.635345  0.076491
# A2ML1     0.087657 -0.077864  0.364210  0.086111 -0.369132  0.362886
# A3GALT2  -0.000840 -0.000320  0.017411  0.022058 -0.059264  0.041225
# ...            ...       ...       ...       ...       ...       ...
# ZXDC      0.622437 -0.362043  0.329705 -0.052570 -1.341316  0.565065
# ZYG11A    0.000755  0.002731  0.018950 -0.006001  0.010520 -0.006595
# ZYG11B    0.948379  0.109532  0.844356  0.361559 -2.229740  0.521776
# ZYX       0.257327  0.088513  0.613831 -0.061584 -0.980731  0.402989
# ZZEF1     0.341421 -0.349972  0.817509 -0.019429 -1.593397  0.644356
#
#           SM-CTDS5  SM-CJFME
# GeneName
# A1BG      0.123176 -0.039893
# A1CF     -0.020575 -0.022954
# A2M       0.320199 -0.122898
# A2ML1    -0.006143 -0.095626
# A3GALT2  -0.017253  0.002151
# ...            ...       ...
# ZXDC      0.780203  0.401880
# ZYG11A    0.023937 -0.020767
# ZYG11B    0.543107  0.185880
# ZYX       0.423348 -0.137888
# ZZEF1     0.704142 -0.168012
#
# [15917 rows x 419 columns]>

# %%
# 读取 ldetect_region.txt 文件
ldetect_path = "/projects/YangLabData/qliu/cTWAS/ldetect_region.txt"

#  delim_whitespace=True
ld_regions = pd.read_csv(ldetect_path, delim_whitespace=True)

# 显示前几行
ld_regions
# Out:
# /tmp/ipykernel_3586760/963290456.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   ld_regions = pd.read_csv(ldetect_path, delim_whitespace=True)
#       chrom     start      stop             region_id
# 0         1     10583   1961168       1_10583_1961168
# 1         1   1961168   3666172     1_1961168_3666172
# 2         1   3666172   4320751     1_3666172_4320751
# 3         1   4320751   5853833     1_4320751_5853833
# 4         1   5853833   7187275     1_5853833_7187275
# ...     ...       ...       ...                   ...
# 1695     22  44599428  46074615  22_44599428_46074615
# 1696     22  46074615  47200568  22_46074615_47200568
# 1697     22  47200568  48507891  22_47200568_48507891
# 1698     22  48507891  49430885  22_48507891_49430885
# 1699     22  49430885  50804870  22_49430885_50804870
#
# [1700 rows x 4 columns]

# %%
max_genes = max(df.shape[0] for df in expression_data.values())
max_genes
# Out:
# 15917

# %%
all_samples = set()
for df in expression_data.values():
    samples = [col for col in df.columns[4:]]
    all_samples.update(samples)
unique_samples = sorted(list(all_samples))
unique_samples
# Out:
# ['MAP15387421',
#  'MAP46246604',
#  'MAP50104134',
#  'MAP50104846',
#  'MAP50106442',
#  'MAP50108462',
#  'MAP50301099',
#  'MAP89164957',
#  'ROS15114174',
#  'ROS20275399',
#  'ROS20376029',
#  'ROS20998065',
#  'ROS21274866',
#  'ROS79590778',
#  'SM-CJEFQ',
#  'SM-CJEFU',
#  'SM-CJEFV',
#  'SM-CJEFX',
#  'SM-CJEG3',
#  'SM-CJEG4',
#  'SM-CJEG7',
#  'SM-CJEG8',
#  'SM-CJEG9',
#  'SM-CJEGA',
#  'SM-CJEGB',
#  'SM-CJEGH',
#  'SM-CJEGI',
#  'SM-CJEGP',
#  'SM-CJEGR',
#  'SM-CJEGX',
#  'SM-CJEH2',
#  'SM-CJEH3',
#  'SM-CJEH6',
#  'SM-CJEHD',
#  'SM-CJEHE',
#  'SM-CJEHK',
#  'SM-CJEHM',
#  'SM-CJEHP',
#  'SM-CJEHU',
#  'SM-CJEHV',
#  'SM-CJEI3',
#  'SM-CJEI5',
#  'SM-CJEI6',
#  'SM-CJEIA',
#  'SM-CJEIB',
#  'SM-CJEIH',
#  'SM-CJEIJ',
#  'SM-CJEIL',
#  'SM-CJEIM',
#  'SM-CJEIN',
#  'SM-CJEIU',
#  'SM-CJEJ2',
#  'SM-CJEJA',
#  'SM-CJEJB',
#  'SM-CJEJJ',
#  'SM-CJEJM',
#  'SM-CJEJO',
#  'SM-CJEJP',
#  'SM-CJEJR',
#  'SM-CJEJT',
#  'SM-CJEJZ',
#  'SM-CJEK3',
#  'SM-CJEK5',
#  'SM-CJEK6',
#  'SM-CJEKE',
#  'SM-CJEKL',
#  'SM-CJFKG',
#  'SM-CJFKU',
#  'SM-CJFL4',
#  'SM-CJFL8',
#  'SM-CJFLT',
#  'SM-CJFLW',
#  'SM-CJFLX',
#  'SM-CJFME',
#  'SM-CJFMO',
#  'SM-CJFN2',
#  'SM-CJFN5',
#  'SM-CJFN8',
#  'SM-CJFN9',
#  'SM-CJFNH',
#  'SM-CJFNJ',
#  'SM-CJFNK',
#  'SM-CJFNM',
#  'SM-CJFNR',
#  'SM-CJFNS',
#  'SM-CJFNY',
#  'SM-CJFO3',
#  'SM-CJFO5',
#  'SM-CJFO7',
#  'SM-CJFO8',
#  'SM-CJFO9',
#  'SM-CJFOF',
#  'SM-CJFOI',
#  'SM-CJFOK',
#  'SM-CJFOP',
#  'SM-CJFOQ',
#  'SM-CJFOS',
#  'SM-CJFOT',
#  'SM-CJFP4',
#  'SM-CJFP7',
#  'SM-CJFPF',
#  'SM-CJGGO',
#  'SM-CJGGR',
#  'SM-CJGGS',
#  'SM-CJGGV',
#  'SM-CJGGW',
#  'SM-CJGGZ',
#  'SM-CJGH8',
#  'SM-CJGH9',
#  'SM-CJGHA',
#  'SM-CJGHB',
#  'SM-CJGHJ',
#  'SM-CJGHN',
#  'SM-CJGHQ',
#  'SM-CJGHS',
#  'SM-CJGHU',
#  'SM-CJGI4',
#  'SM-CJGI5',
#  'SM-CJGI8',
#  'SM-CJGIA',
#  'SM-CJGIB',
#  'SM-CJGIE',
#  'SM-CJGIG',
#  'SM-CJGIH',
#  'SM-CJGII',
#  'SM-CJGIN',
#  'SM-CJGIQ',
#  'SM-CJGIR',
#  'SM-CJGIS',
#  'SM-CJGIT',
#  'SM-CJGIY',
#  'SM-CJGJ2',
#  'SM-CJGJ4',
#  'SM-CJGJ5',
#  'SM-CJGJ7',
#  'SM-CJGJ8',
#  'SM-CJGJ9',
#  'SM-CJGLD',
#  'SM-CJGLE',
#  'SM-CJGLH',
#  'SM-CJGLI',
#  'SM-CJGLJ',
#  'SM-CJGLM',
#  'SM-CJGLP',
#  'SM-CJGLS',
#  'SM-CJGLT',
#  'SM-CJGLV',
#  'SM-CJGLZ',
#  'SM-CJGM3',
#  'SM-CJGM4',
#  'SM-CJGM7',
#  'SM-CJGMH',
#  'SM-CJGMJ',
#  'SM-CJGML',
#  'SM-CJGMP',
#  'SM-CJGMQ',
#  'SM-CJGMU',
#  'SM-CJGMX',
#  'SM-CJGN1',
#  'SM-CJGN2',
#  'SM-CJGN3',
#  'SM-CJGN7',
#  'SM-CJGNB',
#  'SM-CJGNC',
#  'SM-CJGNE',
#  'SM-CJGNF',
#  'SM-CJGNI',
#  'SM-CJGNM',
#  'SM-CJGNN',
#  'SM-CJGNP',
#  'SM-CJGNQ',
#  'SM-CJGNS',
#  'SM-CJGNX',
#  'SM-CJGNZ',
#  'SM-CJGO3',
#  'SM-CJIWT',
#  'SM-CJIWU',
#  'SM-CJIWX',
#  'SM-CJIWY',
#  'SM-CJIX4',
#  'SM-CJIX5',
#  'SM-CJIX6',
#  'SM-CJIXC',
#  'SM-CJIXD',
#  'SM-CJIXG',
#  'SM-CJIXI',
#  'SM-CJIXJ',
#  'SM-CJIXM',
#  'SM-CJIXO',
#  'SM-CJIXP',
#  'SM-CJIXQ',
#  'SM-CJIXR',
#  'SM-CJIXU',
#  'SM-CJIXV',
#  'SM-CJIXW',
#  'SM-CJIXY',
#  'SM-CJIY1',
#  'SM-CJIY2',
#  'SM-CJIY5',
#  'SM-CJIY6',
#  'SM-CJIY7',
#  'SM-CJIYD',
#  'SM-CJIYE',
#  'SM-CJIYF',
#  'SM-CJIYG',
#  'SM-CJIYH',
#  'SM-CJIYK',
#  'SM-CJIYM',
#  'SM-CJIYV',
#  'SM-CJIYX',
#  'SM-CJIZ5',
#  'SM-CJIZF',
#  'SM-CJIZH',
#  'SM-CJIZJ',
#  'SM-CJIZK',
#  'SM-CJIZL',
#  'SM-CJIZP',
#  'SM-CJIZV',
#  'SM-CJIZX',
#  'SM-CJIZY',
#  'SM-CJJ11',
#  'SM-CJJ18',
#  'SM-CJJ1C',
#  'SM-CJJ1D',
#  'SM-CJJ1E',
#  'SM-CJJ1F',
#  'SM-CJJ1H',
#  'SM-CJJ1I',
#  'SM-CJJ1N',
#  'SM-CJJ1O',
#  'SM-CJJ1P',
#  'SM-CJJ1R',
#  'SM-CJJ1S',
#  'SM-CJJ21',
#  'SM-CJJ22',
#  'SM-CJJ23',
#  'SM-CJJ27',
#  'SM-CJJ28',
#  'SM-CJJ2B',
#  'SM-CJJ2D',
#  'SM-CJJ2E',
#  'SM-CJJ2F',
#  'SM-CJJ2G',
#  'SM-CJJ2H',
#  'SM-CJJ2P',
#  'SM-CJJ2Q',
#  'SM-CJJ2V',
#  'SM-CJJ2Z',
#  'SM-CJJ31',
#  'SM-CJJ32',
#  'SM-CJJ34',
#  'SM-CJJ35',
#  'SM-CJJ38',
#  'SM-CJK3B',
#  'SM-CJK3C',
#  'SM-CJK3D',
#  'SM-CJK3O',
#  'SM-CJK3S',
#  'SM-CJK3W',
#  'SM-CJK42',
#  'SM-CJK45',
#  'SM-CJK4A',
#  'SM-CJK4H',
#  'SM-CJK4I',
#  'SM-CJK4Q',
#  'SM-CJK4R',
#  'SM-CJK4S',
#  'SM-CJK4V',
#  'SM-CJK4W',
#  'SM-CJK4X',
#  'SM-CJK4Y',
#  'SM-CJK4Z',
#  'SM-CJK51',
#  'SM-CJK59',
#  'SM-CJK5A',
#  'SM-CJK5B',
#  'SM-CJK5C',
#  'SM-CJK5D',
#  'SM-CJK5F',
#  'SM-CJK5G',
#  'SM-CJK5N',
#  'SM-CTDQE',
#  'SM-CTDQG',
#  'SM-CTDQI',
#  'SM-CTDQJ',
#  'SM-CTDQK',
#  'SM-CTDQM',
#  'SM-CTDQO',
#  'SM-CTDQP',
#  'SM-CTDQQ',
#  'SM-CTDQR',
#  'SM-CTDQT',
#  'SM-CTDQU',
#  'SM-CTDQV',
#  'SM-CTDQX',
#  'SM-CTDQY',
#  'SM-CTDQZ',
#  'SM-CTDR1',
#  'SM-CTDR2',
#  'SM-CTDR3',
#  'SM-CTDR4',
#  'SM-CTDR5',
#  'SM-CTDR6',
#  'SM-CTDRB',
#  'SM-CTDRH',
#  'SM-CTDRI',
#  'SM-CTDRJ',
#  'SM-CTDRM',
#  'SM-CTDRN',
#  'SM-CTDRO',
#  'SM-CTDS4',
#  'SM-CTDS5',
#  'SM-CTDS6',
#  'SM-CTDS7',
#  'SM-CTDSD',
#  'SM-CTDSF',
#  'SM-CTDSG',
#  'SM-CTDSI',
#  'SM-CTDSJ',
#  'SM-CTDSK',
#  'SM-CTDSR',
#  'SM-CTDST',
#  'SM-CTDSW',
#  'SM-CTDSY',
#  'SM-CTDT1',
#  'SM-CTDT2',
#  'SM-CTDT7',
#  'SM-CTDTF',
#  'SM-CTDTG',
#  'SM-CTDTH',
#  'SM-CTDTI',
#  'SM-CTDTM',
#  'SM-CTDTN',
#  'SM-CTDTO',
#  'SM-CTDTP',
#  'SM-CTDTQ',
#  'SM-CTDTR',
#  'SM-CTDTV',
#  'SM-CTDTW',
#  'SM-CTDTX',
#  'SM-CTDTY',
#  'SM-CTDTZ',
#  'SM-CTDU2',
#  'SM-CTDU4',
#  'SM-CTDU7',
#  'SM-CTDU8',
#  'SM-CTDU9',
#  'SM-CTDUP',
#  'SM-CTDV1',
#  'SM-CTDV6',
#  'SM-CTDVD',
#  'SM-CTDVP',
#  'SM-CTECF',
#  'SM-CTECI',
#  'SM-CTECL',
#  'SM-CTECQ',
#  'SM-CTECR',
#  'SM-CTECU',
#  'SM-CTECV',
#  'SM-CTED1',
#  'SM-CTED2',
#  'SM-CTED8',
#  'SM-CTEDA',
#  'SM-CTEDC',
#  'SM-CTEDG',
#  'SM-CTEDO',
#  'SM-CTEDS',
#  'SM-CTEDW',
#  'SM-CTEDZ',
#  'SM-CTEE3',
#  'SM-CTEE5',
#  'SM-CTEEA',
#  'SM-CTEEF',
#  'SM-CTEEG',
#  'SM-CTEEH',
#  'SM-CTEEU',
#  'SM-CTEEZ',
#  'SM-CTEF7',
#  'SM-CTEF8',
#  'SM-CTEFA',
#  'SM-CTEFC',
#  'SM-CTEFD',
#  'SM-CTEFE',
#  'SM-CTEFH',
#  'SM-CTEFK',
#  'SM-CTEFL',
#  'SM-CTEFU',
#  'SM-CTEFX',
#  'SM-CTEFZ',
#  'SM-CTEG4',
#  'SM-CTEG8',
#  'SM-CTEG9',
#  'SM-CTEGD',
#  'SM-CTEGF',
#  'SM-CTEGH',
#  'SM-CTEGQ',
#  'SM-CTEGR',
#  'SM-CTEGS',
#  'SM-CTEGV',
#  'SM-CTEGW',
#  'SM-CTEI5',
#  'SM-CTEIC',
#  'SM-CTEIP',
#  'SM-CTEM6',
#  'SM-CTEMM',
#  'SM-CTEMU',
#  'SM-CTEMW',
#  'SM-CTEMY',
#  'SM-CTEN2',
#  'SM-CTEN3',
#  'SM-CTEN5',
#  'SM-CTEN7',
#  'SM-CTEND',
#  'SM-CTENF',
#  'SM-CTENG']

# %% [markdown]
# # Save sample list

# %%
with open("sample_list.txt", "w") as f:
    for sample in unique_samples:
        f.write(f"{sample}\n")

# %%
num_samples = len(unique_samples)
num_samples
# Out:
# 415

# %%
num_cell_types = len(expression_data)
num_cell_types
# Out:
# 6

# %%
import numpy as np
# 2. 创建一个空的 3D 张量
tensor_3d = np.zeros((max_genes, num_cell_types, num_samples))

# 3. 用数据填充张量
cell_types = list(expression_data.keys())  # 保持细胞类型的顺序
gene_list = None

for i, cell_type in enumerate(cell_types):
    df = expression_data[cell_type]
    current_genes = df.index.tolist()

    if gene_list is None:
        gene_list = sorted(current_genes)
        gene_to_index = {gene: idx for idx, gene in enumerate(gene_list)}
        max_genes = len(gene_list)
        # Re-initialize tensor with the correct max_genes based on the union of genes
        tensor_3d = np.zeros((max_genes, num_cell_types, num_samples))
    elif sorted(current_genes) != gene_list:
        print(f"Warning: Genes in {cell_type} do not match the initial gene list. Filling with NaN where genes are missing.")

    for j, sample in enumerate(unique_samples):
        if sample in df.columns:
            for gene, expression_value in df[sample].items():
                if gene in gene_to_index:
                    tensor_3d[gene_to_index[gene], i, j] = expression_value
                else:
                    pass # Gene not in the common gene list
        else:
            tensor_3d[:len(current_genes), i, j] = np.nan # Sample not present for this cell type

print("3D tensor shape:", tensor_3d.shape)
print("gene order (first dimension):", gene_list[:10] if gene_list else None)
print("cell type order (second dimension):", cell_types)
print("sample order (third dimension):", unique_samples[:10])
# Out:
# 3D tensor shape: (15917, 6, 415)
# gene order (first dimension): ['A1BG', 'A1CF', 'A2M', 'A2ML1', 'A3GALT2', 'A4GALT', 'A4GNT', 'AAAS', 'AACS', 'AADAC']
# cell type order (second dimension): ['Astrocytes', 'Excitatory_Neurons', 'Inhibitory_Neurons', 'Microglia', 'Oligodendrocytes', 'OPCs']
# sample order (third dimension): ['MAP15387421', 'MAP46246604', 'MAP50104134', 'MAP50104846', 'MAP50106442', 'MAP50108462', 'MAP50301099', 'MAP89164957', 'ROS15114174', 'ROS20275399']

# %%
gene_info = expression_data["Excitatory_Neurons"].iloc[:,:4]
gene_info
# Out:
#           CHROM  GeneStart    GeneEnd         TargetID
# GeneName
# A1BG         19   58345178   58353492  ENSG00000121410
# A1CF         10   50799409   50885675  ENSG00000148584
# A2M          12    9067664    9116229  ENSG00000175899
# A2ML1        12    8822621    8887001  ENSG00000166535
# A3GALT2       1   33306766   33321098  ENSG00000184389
# ...         ...        ...        ...              ...
# ZXDC          3  126437601  126475891  ENSG00000070476
# ZYG11A        1   52842511   52894998  ENSG00000203995
# ZYG11B        1   52726453   52827336  ENSG00000162378
# ZYX           7  143381295  143391111  ENSG00000159840
# ZZEF1        17    4004445    4143030  ENSG00000074755
#
# [15917 rows x 4 columns]

# %%
ld_regions
# Out:
#       chrom     start      stop             region_id
# 0         1     10583   1961168       1_10583_1961168
# 1         1   1961168   3666172     1_1961168_3666172
# 2         1   3666172   4320751     1_3666172_4320751
# 3         1   4320751   5853833     1_4320751_5853833
# 4         1   5853833   7187275     1_5853833_7187275
# ...     ...       ...       ...                   ...
# 1695     22  44599428  46074615  22_44599428_46074615
# 1696     22  46074615  47200568  22_46074615_47200568
# 1697     22  47200568  48507891  22_47200568_48507891
# 1698     22  48507891  49430885  22_48507891_49430885
# 1699     22  49430885  50804870  22_49430885_50804870
#
# [1700 rows x 4 columns]

# %% [markdown]
# # Construct Analysis region

# %%
gene_df =gene_info.reset_index()
region_df = ld_regions.rename(columns={"chrom": "CHROM", "start": "RegionStart", "stop": "RegionEnd"})
region_gene_map = {}
for idx, region in region_df.iterrows():
    chrom = region['CHROM']
    r_start = region['RegionStart']
    r_end = region['RegionEnd']
    region_id = region['region_id']

    # 筛选染色体一致、并且存在重叠的基因
    overlap_genes = gene_df[
        (gene_df['CHROM'] == chrom) &
        (gene_df['GeneEnd'] >= r_start) &
        (gene_df['GeneStart'] <= r_end)
    ]

    # 提取所需信息
    gene_names = overlap_genes['GeneName'].tolist()
    if not overlap_genes.empty:
        region_gene_map[region_id] = {
            'genes': gene_names,
            'region_gene_start': overlap_genes['GeneStart'].min(),
            'region_gene_end': overlap_genes['GeneEnd'].max()
        }
    else:
        region_gene_map[region_id] = {
            'genes': [],
            'region_gene_start': None,
            'region_gene_end': None
        }

# %%
region_gene_map
# Out:
# {'1_10583_1961168': {'genes': ['ACAP3',
#    'AGRN',
#    'AL645728.1',
#    'ANKRD65',
#    'ATAD3A',
#    'ATAD3B',
#    'ATAD3C',
#    'AURKAIP1',
#    'B3GALT6',
#    'C1orf159',
#    'CALML6',
#    'CCNL2',
#    'CDK11A',
#    'CDK11B',
#    'CFAP74',
#    'CPTP',
#    'DVL1',
#    'GNB1',
#    'HES4',
#    'ISG15',
#    'KLHL17',
#    'MIB2',
#    'MMP23B',
#    'MXRA8',
#    'NADK',
#    'NOC2L',
#    'PERM1',
#    'PLEKHN1',
#    'PUSL1',
#    'SAMD11',
#    'SCNN1D',
#    'SDF4',
#    'SLC35E2B',
#    'SSU72',
#    'TAS1R3',
#    'TMEM240',
#    'TMEM52',
#    'TMEM88B',
#    'TNFRSF18',
#    'TNFRSF4',
#    'TTLL10',
#    'UBE2J2',
#    'VWA1'],
#   'region_gene_start': np.int64(923928),
#   'region_gene_end': np.int64(2003837)},
#  '1_1961168_3666172': {'genes': ['ARHGEF16',
#    'CFAP74',
#    'GABRD',
#    'HES5',
#    'MEGF6',
#    'MMEL1',
#    'MORN1',
#    'PANK4',
#    'PEX10',
#    'PLCH2',
#    'PRDM16',
#    'PRKCZ',
#    'RER1',
#    'SKI',
#    'TNFRSF14',
#    'TP73',
#    'TPRG1L',
#    'TTC34',
#    'WRAP73'],
#   'region_gene_start': np.int64(1921951),
#   'region_gene_end': np.int64(3736201)},
#  '1_3666172_4320751': {'genes': ['C1orf174',
#    'CCDC27',
#    'CEP104',
#    'DFFB',
#    'LRRC47',
#    'SMIM1',
#    'TP73'],
#   'region_gene_start': np.int64(3652516),
#   'region_gene_end': np.int64(3900293)},
#  '1_4320751_5853833': {'genes': ['AJAP1'],
#   'region_gene_start': np.int64(4654609),
#   'region_gene_end': np.int64(4792534)},
#  '1_5853833_7187275': {'genes': ['ACOT7',
#    'CAMTA1',
#    'CHD5',
#    'DNAJC11',
#    'ESPN',
#    'GPR153',
#    'HES2',
#    'ICMT',
#    'KCNAB2',
#    'KLHL21',
#    'NOL9',
#    'NPHP4',
#    'PHF13',
#    'PLEKHG5',
#    'RNF207',
#    'TAS1R1',
#    'THAP3',
#    'TNFRSF25',
#    'ZBTB48'],
#   'region_gene_start': np.int64(5862811),
#   'region_gene_end': np.int64(7769706)},
#  '1_7187275_9305140': {'genes': ['CA6',
#    'CAMTA1',
#    'ENO1',
#    'ERRFI1',
#    'GPR157',
#    'H6PD',
#    'PARK7',
#    'PER3',
#    'RERE',
#    'SLC2A5',
#    'SLC2A7',
#    'SLC45A1',
#    'SPSB1',
#    'TNFRSF9',
#    'UTS2',
#    'VAMP3'],
#   'region_gene_start': np.int64(6785454),
#   'region_gene_end': np.int64(9369532)},
#  '1_9305140_10746927': {'genes': ['AL357140.1',
#    'CASZ1',
#    'CLSTN1',
#    'CORT',
#    'CTNNBIP1',
#    'DFFA',
#    'KIF1B',
#    'LZIC',
#    'NMNAT1',
#    'PEX14',
#    'PGD',
#    'PIK3CD',
#    'RBP7',
#    'SLC25A33',
#    'SPSB1',
#    'TMEM201',
#    'UBE4B'],
#   'region_gene_start': np.int64(9292894),
#   'region_gene_end': np.int64(10796650)},
#  '1_10746927_11717784': {'genes': ['ANGPTL7',
#    'C1orf127',
#    'CASZ1',
#    'DRAXIN',
#    'EXOSC10',
#    'FBXO2',
#    'FBXO44',
#    'FBXO6',
#    'MAD2L2',
#    'MASP2',
#    'MTOR',
#    'SRM',
#    'TARDBP',
#    'UBIAD1'],
#   'region_gene_start': np.int64(10636604),
#   'region_gene_end': np.int64(11725857)},
#  '1_11717784_12719464': {'genes': ['AADACL3',
#    'AADACL4',
#    'AGTRAP',
#    'C1orf167',
#    'CLCN6',
#    'DHRS3',
#    'DRAXIN',
#    'KIAA2013',
#    'MFN2',
#    'MIIP',
#    'MTHFR',
#    'NPPA',
#    'NPPB',
#    'PLOD1',
#    'TNFRSF1B',
#    'TNFRSF8',
#    'VPS13D'],
#   'region_gene_start': np.int64(11691710),
#   'region_gene_end': np.int64(12728760)},
#  '1_12719464_14565015': {'genes': ['AADACL3',
#    'C1orf158',
#    'KAZN',
#    'LRRC38',
#    'PDPN',
#    'PRAMEF20',
#    'PRDM2'],
#   'region_gene_start': np.int64(12716110),
#   'region_gene_end': np.int64(15118043)},
#  '1_14565015_16571235': {'genes': ['AGMAT',
#    'ARHGEF19',
#    'C1orf195',
#    'CASP9',
#    'CELA2A',
#    'CELA2B',
#    'CLCNKA',
#    'CLCNKB',
#    'CTRC',
#    'DDI2',
#    'DNAJC16',
#    'EFHD2',
#    'EPHA2',
#    'FAM131C',
#    'FBLIM1',
#    'FBXO42',
#    'FHAD1',
#    'HSPB7',
#    'KAZN',
#    'NBPF1',
#    'NECAP2',
#    'PLEKHM2',
#    'SLC25A34',
#    'SPATA21',
#    'SPEN',
#    'SZRD1',
#    'TMEM51',
#    'TMEM82',
#    'UQCRHL',
#    'ZBTB17'],
#   'region_gene_start': np.int64(13892792),
#   'region_gene_end': np.int64(16613562)},
#  '1_16571235_18336405': {'genes': ['ACTL8',
#    'ARHGEF10L',
#    'ATP13A2',
#    'CROCC',
#    'IGSF21',
#    'MFAP2',
#    'NBPF1',
#    'PADI1',
#    'PADI2',
#    'PADI3',
#    'PADI4',
#    'PADI6',
#    'RCC2',
#    'SDHB'],
#   'region_gene_start': np.int64(16562319),
#   'region_gene_end': np.int64(18378483)},
#  '1_18336405_20142656': {'genes': ['AKR7A2',
#    'AKR7A3',
#    'ALDH4A1',
#    'CAPZB',
#    'EMC1',
#    'HTR6',
#    'IFFO2',
#    'IGSF21',
#    'MRTO4',
#    'NBL1',
#    'OTUD3',
#    'PAX7',
#    'PLA2G2D',
#    'PLA2G2F',
#    'PLA2G5',
#    'TMCO4',
#    'UBR4'],
#   'region_gene_start': np.int64(18107798),
#   'region_gene_end': np.int64(20150381)},
#  '1_20142656_21410095': {'genes': ['CAMK2N1',
#    'CDA',
#    'DDOST',
#    'ECE1',
#    'EIF4G3',
#    'FAM43B',
#    'HP1BP3',
#    'KIF17',
#    'MUL1',
#    'PINK1',
#    'PLA2G2C',
#    'PLA2G2F',
#    'SH2D5',
#    'UBXN10',
#    'VWA5B1'],
#   'region_gene_start': np.int64(20139323),
#   'region_gene_end': np.int64(21345572)},
#  '1_21410095_22760390': {'genes': ['ALPL',
#    'C1QA',
#    'C1QB',
#    'C1QC',
#    'CDC42',
#    'CELA3A',
#    'CELA3B',
#    'EPHA8',
#    'EPHB2',
#    'HSPG2',
#    'LDLRAD2',
#    'NBPF3',
#    'RAP1GAP',
#    'USP48',
#    'WNT4',
#    'ZBTB40'],
#   'region_gene_start': np.int64(21440128),
#   'region_gene_end': np.int64(22921500)},
#  '1_22760390_23594100': {'genes': ['ASAP3',
#    'E2F2',
#    'EPHB2',
#    'HNRNPR',
#    'HTR1D',
#    'ID3',
#    'KDM1A',
#    'LACTBL1',
#    'LUZP1',
#    'MDS2',
#    'TCEA3',
#    'ZNF436'],
#   'region_gene_start': np.int64(22710839),
#   'region_gene_end': np.int64(23640568)},
#  '1_23594100_25190354': {'genes': ['CLIC4',
#    'CNR2',
#    'FUCA1',
#    'GALE',
#    'GRHL3',
#    'HMGCL',
#    'IFNLR1',
#    'IL22RA1',
#    'LYPLA2',
#    'MDS2',
#    'MYOM3',
#    'NCMAP',
#    'NIPAL3',
#    'PITHD1',
#    'PNRC2',
#    'RCAN3',
#    'RUNX3',
#    'SRRM1',
#    'SRSF10',
#    'STPG1'],
#   'region_gene_start': np.int64(23581495),
#   'region_gene_end': np.int64(24965121)},
#  '1_25190354_27075376': {'genes': ['ARID1A',
#    'AUNIP',
#    'CATSPER4',
#    'CD52',
#    'CEP85',
#    'CNKSR1',
#    'DHDDS',
#    'EXTL1',
#    'FAM110D',
#    'GPATCH3',
#    'GPN2',
#    'HMGN2',
#    'KDF1',
#    'LDLRAP1',
#    'LIN28A',
#    'MAN1C1',
#    'MTFR1L',
#    'NUDC',
#    'PAFAH2',
#    'PAQR7',
#    'PDIK1L',
#    'PIGV',
#    'RHCE',
#    'RHD',
#    'RPS6KA1',
#    'RSRP1',
#    'SFN',
#    'SH3BGRL3',
#    'SLC30A2',
#    'STMN1',
#    'SYF2',
#    'TMEM50A',
#    'TRIM63',
#    'TRNP1',
#    'UBXN11',
#    'ZDHHC18',
#    'ZNF593'],
#   'region_gene_start': np.int64(25222276),
#   'region_gene_end': np.int64(27000886)},
#  '1_27075376_29689034': {'genes': ['AHDC1',
#    'CD164L2',
#    'DNAJC8',
#    'EPB41',
#    'EYA3',
#    'FAM76A',
#    'FCN3',
#    'FGR',
#    'GMEB1',
#    'GPR3',
#    'IFI6',
#    'MAP3K6',
#    'MECR',
#    'MED18',
#    'OPRD1',
#    'PHACTR4',
#    'PPP1R8',
#    'PTAFR',
#    'PTPRU',
#    'RAB42',
#    'RCC1',
#    'RPA2',
#    'SESN2',
#    'SLC9A1',
#    'SMPDL3B',
#    'SRSF4',
#    'STX12',
#    'SYTL1',
#    'TAF12',
#    'THEMIS2',
#    'TMEM200B',
#    'TMEM222',
#    'TRNAU1AP',
#    'WASF2',
#    'WDTC1',
#    'XKR8',
#    'YTHDF2'],
#   'region_gene_start': np.int64(27098809),
#   'region_gene_end': np.int64(29326813)},
#  '1_29689034_31973084': {'genes': ['COL16A1',
#    'FABP3',
#    'HCRTR1',
#    'LAPTM5',
#    'MATN1',
#    'NKAIN1',
#    'PEF1',
#    'PTP4A2',
#    'PUM1',
#    'SDC3',
#    'SERINC2',
#    'SNRNP40',
#    'SPOCD1',
#    'TINAGL1',
#    'ZCCHC17'],
#   'region_gene_start': np.int64(30711277),
#   'region_gene_end': np.int64(31944856)},
#  '1_31973084_34334157': {'genes': ['A3GALT2',
#    'AK2',
#    'AZIN2',
#    'BSDC1',
#    'C1orf94',
#    'CCDC28B',
#    'CSMD2',
#    'DCDC2B',
#    'EIF3I',
#    'FAM167B',
#    'FAM229A',
#    'FNDC5',
#    'HDAC1',
#    'HMGB4',
#    'HPCA',
#    'IQCC',
#    'KHDRBS1',
#    'KIAA1522',
#    'KPNA6',
#    'LCK',
#    'MARCKSL1',
#    'PHC2',
#    'RBBP4',
#    'RNF19B',
#    'S100PBP',
#    'SYNC',
#    'TMEM234',
#    'TMEM39B',
#    'TMEM54',
#    'TRIM62',
#    'TSSK3',
#    'TXLNA',
#    'ZBTB8A',
#    'ZBTB8B',
#    'ZBTB8OS',
#    'ZNF362',
#    'ZSCAN20'],
#   'region_gene_start': np.int64(32013868),
#   'region_gene_end': np.int64(34219131)},
#  '1_34334157_37083582': {'genes': ['AGO1',
#    'AGO3',
#    'AGO4',
#    'C1orf216',
#    'CLSPN',
#    'COL8A2',
#    'CSF3R',
#    'DLGAP3',
#    'EVA1B',
#    'GJA4',
#    'GJB3',
#    'GJB4',
#    'GJB5',
#    'GRIK3',
#    'KIAA0319L',
#    'LSM10',
#    'MAP7D1',
#    'NCDN',
#    'OSCP1',
#    'PSMB2',
#    'SFPQ',
#    'SH3D21',
#    'SMIM12',
#    'STK40',
#    'TEKT2',
#    'TFAP2E',
#    'THRAP3',
#    'TRAPPC3',
#    'ZMYM1',
#    'ZMYM4',
#    'ZMYM6'],
#   'region_gene_start': np.int64(34712737),
#   'region_gene_end': np.int64(37034515)},
#  '1_37083582_38266175': {'genes': ['C1orf109',
#    'C1orf122',
#    'CDCA8',
#    'DNALI1',
#    'EPHA10',
#    'FHL3',
#    'GNL2',
#    'INPP5B',
#    'MANEAL',
#    'MEAF6',
#    'MTF1',
#    'POU3F1',
#    'RSPO1',
#    'SF3A3',
#    'SNIP1',
#    'YRDC',
#    'ZC3H12A'],
#   'region_gene_start': np.int64(37474580),
#   'region_gene_end': np.int64(38046793)},
#  '1_38266175_39734895': {'genes': ['AKIRIN1',
#    'BMP8A',
#    'GJA9',
#    'HEYL',
#    'HPCAL4',
#    'MACF1',
#    'MYCBP',
#    'NDUFS5',
#    'NT5C1A',
#    'PABPC4',
#    'PPIE',
#    'RHBDL2',
#    'RRAGC'],
#   'region_gene_start': np.int64(38838198),
#   'region_gene_end': np.int64(39763914)},
#  '1_39734895_41509656': {'genes': ['BMP8B',
#    'CAP1',
#    'CITED4',
#    'COL9A2',
#    'CTPS1',
#    'EXO5',
#    'FOXO6',
#    'HIVEP3',
#    'KCNQ4',
#    'MFSD2A',
#    'MYCL',
#    'NFYC',
#    'OXCT2',
#    'PPIE',
#    'PPT1',
#    'RIMS3',
#    'RLF',
#    'SCMH1',
#    'SLFNL1',
#    'SMAP2',
#    'TMCO2',
#    'TRIT1',
#    'ZFP69',
#    'ZFP69B',
#    'ZMPSTE24',
#    'ZNF684'],
#   'region_gene_start': np.int64(39692182),
#   'region_gene_end': np.int64(42035925)},
#  '1_41509656_43292786': {'genes': ['C1orf50',
#    'CCDC30',
#    'CFAP57',
#    'CLDN19',
#    'EBNA1BP2',
#    'ERMAP',
#    'FOXJ3',
#    'HIVEP3',
#    'P3H1',
#    'PPCS',
#    'PPIH',
#    'RIMKLA',
#    'SLC2A1',
#    'TMEM125',
#    'YBX1',
#    'ZMYND12',
#    'ZNF691'],
#   'region_gene_start': np.int64(41506365),
#   'region_gene_end': np.int64(43274002)},
#  '1_43292786_44503511': {'genes': ['ARTN',
#    'ATP6V0B',
#    'B4GALT2',
#    'CCDC24',
#    'CDC20',
#    'DMAP1',
#    'DPH2',
#    'ELOVL1',
#    'ERI3',
#    'HYI',
#    'IPO13',
#    'KDM4A',
#    'KLF17',
#    'MED8',
#    'MPL',
#    'PTPRF',
#    'RNF220',
#    'SLC6A9',
#    'ST3GAL3',
#    'SZT2',
#    'TIE1'],
#   'region_gene_start': np.int64(43300982),
#   'region_gene_end': np.int64(44651724)},
#  '1_44503511_46433829': {'genes': ['AKR1A1',
#    'BEST4',
#    'BTBD19',
#    'CCDC17',
#    'EIF2B3',
#    'FAAH',
#    'GPBP1L1',
#    'HECTD3',
#    'HPDL',
#    'IPP',
#    'KIF2C',
#    'LRRC41',
#    'LURAP1',
#    'MAST2',
#    'MMACHC',
#    'MUTYH',
#    'NASP',
#    'NSUN4',
#    'PIK3R3',
#    'PLK3',
#    'POMGNT1',
#    'PRDX1',
#    'PTCH2',
#    'RAD54L',
#    'RNF220',
#    'TESK2',
#    'TMEM53',
#    'TMEM69',
#    'TOE1',
#    'TSPAN1',
#    'UQCRH',
#    'UROD',
#    'ZSWIM5'],
#   'region_gene_start': np.int64(44405194),
#   'region_gene_end': np.int64(46413848)},
#  '1_46433829_47536904': {'genes': ['ATPAF1',
#    'CMPK1',
#    'CYP4A11',
#    'CYP4A22',
#    'CYP4B1',
#    'CYP4X1',
#    'CYP4Z1',
#    'EFCAB14',
#    'FOXD2',
#    'FOXE3',
#    'KNCN',
#    'MKNK1',
#    'MOB3C',
#    'STIL',
#    'TAL1',
#    'TEX38'],
#   'region_gene_start': np.int64(46545641),
#   'region_gene_end': np.int64(47440691)},
#  '1_47536904_48512516': {'genes': ['AL109659.1',
#    'SLC5A9',
#    'SPATA6',
#    'TRABD2B'],
#   'region_gene_start': np.int64(47760528),
#   'region_gene_end': np.int64(48472208)},
#  '1_48512516_49428505': {'genes': ['AGBL4', 'BEND5'],
#   'region_gene_start': np.int64(48532854),
#   'region_gene_end': np.int64(50023954)},
#  '1_49428505_51248054': {'genes': ['AGBL4',
#    'C1orf185',
#    'CDKN2C',
#    'DMRTA2',
#    'ELAVL4',
#    'FAF1',
#    'RNF11'],
#   'region_gene_start': np.int64(48532854),
#   'region_gene_end': np.int64(51273447)},
#  '1_51248054_53760589': {'genes': ['AL445183.1',
#    'BTF3L4',
#    'CC2D1B',
#    'COA7',
#    'CPT2',
#    'DMRTB1',
#    'ECHDC2',
#    'EPS15',
#    'GLIS1',
#    'GPX7',
#    'KTI12',
#    'LRP8',
#    'MAGOH',
#    'ORC1',
#    'OSBPL9',
#    'PODN',
#    'PRPF38A',
#    'RAB3B',
#    'RNF11',
#    'SCP2',
#    'SLC1A7',
#    'TTC39A',
#    'TXNDC12',
#    'ZFYVE9',
#    'ZYG11A',
#    'ZYG11B'],
#   'region_gene_start': np.int64(51236273),
#   'region_gene_end': np.int64(53738106)},
#  '1_53760589_55947444': {'genes': ['ACOT11',
#    'BSND',
#    'CDCP2',
#    'CYB5RL',
#    'DHCR24',
#    'DIO1',
#    'FAM151A',
#    'HSPB11',
#    'LDLRAD1',
#    'LRRC42',
#    'MROH7',
#    'NDC1',
#    'PARS2',
#    'PCSK9',
#    'SSBP3',
#    'TCEANC2',
#    'TMEM59',
#    'TMEM61',
#    'TTC22',
#    'TTC4',
#    'USP24',
#    'YIPF1'],
#   'region_gene_start': np.int64(53765478),
#   'region_gene_end': np.int64(55215364)},
#  '1_55947444_56556055': {'genes': [],
#   'region_gene_start': None,
#   'region_gene_end': None},
#  '1_56556055_58399727': {'genes': ['C8A', 'C8B', 'DAB1', 'PRKAA2'],
#   'region_gene_start': np.int64(56645314),
#   'region_gene_end': np.int64(58546734)},
#  '1_58399727_59424737': {'genes': ['DAB1',
#    'FGGY',
#    'JUN',
#    'MYSM1',
#    'OMA1',
#    'TACSTD2'],
#   'region_gene_start': np.int64(56994778),
#   'region_gene_end': np.int64(59810647)},
#  '1_59424737_61456693': {'genes': ['C1orf87',
#    'CYP2J2',
#    'FGGY',
#    'HOOK1',
#    'NFIA'],
#   'region_gene_start': np.int64(59296638),
#   'region_gene_end': np.int64(61462788)},
#  '1_61456693_62989418': {'genes': ['ANGPTL3',
#    'ATG4C',
#    'DOCK7',
#    'KANK4',
#    'L1TD1',
#    'NFIA',
#    'TM2D1',
#    'USP1'],
#   'region_gene_start': np.int64(60865259),
#   'region_gene_end': np.int64(62865516)},
#  '1_62989418_64576021': {'genes': ['ALG6',
#    'CACHD1',
#    'EFCAB7',
#    'ITGB3BP',
#    'PGM1',
#    'ROR1',
#    'UBE2U'],
#   'region_gene_start': np.int64(63367575),
#   'region_gene_end': np.int64(64693058)},
#  '1_64576021_66473721': {'genes': ['AK4',
#    'CACHD1',
#    'DNAJC6',
#    'JAK1',
#    'LEPR',
#    'LEPROT',
#    'PDE4B',
#    'RAVER2'],
#   'region_gene_start': np.int64(64470129),
#   'region_gene_end': np.int64(66374579)},
#  '1_66473721_68012212': {'genes': ['C1orf141',
#    'GADD45A',
#    'GNG12',
#    'IL12RB2',
#    'IL23R',
#    'INSL5',
#    'MIER1',
#    'SERBP1',
#    'SGIP1',
#    'SLC35D1',
#    'TCTEX1D1',
#    'WDR78'],
#   'region_gene_start': np.int64(66533383),
#   'region_gene_end': np.int64(67833467)},
#  '1_68012212_69221933': {'genes': ['DEPDC1', 'DIRAS3', 'RPE65', 'WLS'],
#   'region_gene_start': np.int64(68045886),
#   'region_gene_end': np.int64(68497221)},
#  '1_69221933_70906787': {'genes': ['ANKRD13C',
#    'CTH',
#    'HHLA3',
#    'LRRC40',
#    'LRRC7',
#    'PTGER3',
#    'SRSF11'],
#   'region_gene_start': np.int64(69567922),
#   'region_gene_end': np.int64(71047808)},
#  '1_70906787_71218722': {'genes': ['PTGER3', 'ZRANB2'],
#   'region_gene_start': np.int64(70852353),
#   'region_gene_end': np.int64(71081289)},
#  '1_71218722_73861224': {'genes': ['NEGR1'],
#   'region_gene_start': np.int64(71395943),
#   'region_gene_end': np.int64(72282539)},
#  '1_73861224_76262450': {'genes': ['ACADM',
#    'ASB17',
#    'CRYZ',
#    'ERICH3',
#    'FPGT',
#    'LHX8',
#    'LRRC53',
#    'LRRIQ3',
#    'MSH4',
#    'RABGGTB',
#    'SLC44A5',
#    'ST6GALNAC3',
#    'TNNI3K',
#    'TYW3'],
#   'region_gene_start': np.int64(74026015),
#   'region_gene_end': np.int64(76634603)},
#  '1_76262450_79195513': {'genes': ['AK5',
#    'DNAJB4',
#    'FUBP1',
#    'GIPC2',
#    'IFI44',
#    'IFI44L',
#    'NEXN',
#    'PIGK',
#    'PTGFR',
#    'ST6GALNAC3',
#    'ST6GALNAC5',
#    'USP33'],
#   'region_gene_start': np.int64(76074746),
#   'region_gene_end': np.int64(78664078)},
#  '1_79195513_80888506': {'genes': [],
#   'region_gene_start': None,
#   'region_gene_end': None},
#  '1_80888506_83526065': {'genes': [],
#   'region_gene_start': None,
#   'region_gene_end': None},
#  '1_83526065_84378812': {'genes': ['PRKACB', 'SAMD13', 'TTLL7'],
#   'region_gene_start': np.int64(83865024),
#   'region_gene_end': np.int64(84389957)},
#  '1_84378812_85989068': {'genes': ['BCL10',
#    'C1orf52',
#    'COL24A1',
#    'CTBS',
#    'DDAH1',
#    'DNASE2B',
#    'GNG5',
#    'LPAR3',
#    'MCOLN2',
#    'MCOLN3',
#    'RPF1',
#    'SAMD13',
#    'SSX2IP',
#    'SYDE2',
#    'WDR63',
#    'ZNHIT6'],
#   'region_gene_start': np.int64(84298366),
#   'region_gene_end': np.int64(86156943)},
#  '1_85989068_87662948': {'genes': ['CLCA1',
#    'CLCA2',
#    'CLCA4',
#    'COL24A1',
#    'HS2ST1',
#    'LMO4',
#    'ODF2L',
#    'SH3GLB1'],
#   'region_gene_start': np.int64(85729233),
#   'region_gene_end': np.int64(87348923)},
#  '1_87662948_89600744': {'genes': ['GBP1',
#    'GBP2',
#    'GBP3',
#    'GBP4',
#    'GBP5',
#    'GBP6',
#    'GBP7',
#    'GTF2B',
#    'LRRC8B',
#    'PKN2',
#    'RBMXL1'],
#   'region_gene_start': np.int64(88684222),
#   'region_gene_end': np.int64(89597864)},
#  '1_89600744_91420760': {'genes': ['HFM1',
#    'LRRC8C',
#    'LRRC8D',
#    'ZNF326',
#    'ZNF644'],
#   'region_gene_start': np.int64(89633072),
#   'region_gene_end': np.int64(91404856)},
#  '1_91420760_93070902': {'genes': ['BRDT',
#    'BTBD8',
#    'C1orf146',
#    'CDC7',
#    'EPHX4',
#    'EVI5',
#    'GFI1',
#    'GLMN',
#    'RPAP2',
#    'TGFBR3'],
#   'region_gene_start': np.int64(91500851),
#   'region_gene_end': np.int64(92792404)},
#  '1_93070902_94040635': {'genes': ['ABCA4',
#    'BCAR3',
#    'CCDC18',
#    'DNTTIP2',
#    'DR1',
#    'FNBP1L',
#    'GCLM',
#    'MTF2',
#    'TMED5'],
#   'region_gene_start': np.int64(93079235),
#   'region_gene_end': np.int64(94121148)},
#  '1_94040635_95685337': {'genes': ['ABCA4',
#    'ABCD3',
#    'ALG14',
#    'ARHGAP29',
#    'CNN3',
#    'F3',
#    'RWDD3',
#    'SLC44A3'],
#   'region_gene_start': np.int64(93992834),
#   'region_gene_end': np.int64(95247225)},
#  '1_95685337_97419693': {'genes': ['DPYD', 'PTBP2'],
#   'region_gene_start': np.int64(96721665),
#   'region_gene_end': np.int64(97995000)},
#  '1_97419693_99335048': {'genes': ['DPYD', 'SNX7'],
#   'region_gene_start': np.int64(97077743),
#   'region_gene_end': np.int64(98760500)},
#  '1_99335048_100360849': {'genes': ['AGL',
#    'CDC14A',
#    'DBT',
#    'FRRS1',
#    'LRRC39',
#    'PALMD',
#    'RTCA',
#    'SASS6',
#    'SLC35A3',
#    'TRMT13'],
#   'region_gene_start': np.int64(99646113),
#   'region_gene_end': np.int64(100520277)},
#  '1_100360849_101575460': {'genes': ['CDC14A',
#    'DPH5',
#    'EXTL2',
#    'GPR88',
#    'S1PR1',
#    'SLC30A7',
#    'VCAM1'],
#   'region_gene_start': np.int64(100345001),
#   'region_gene_end': np.int64(101243713)},
#  '1_101575460_102433189': {'genes': ['OLFM3'],
#   'region_gene_start': np.int64(101802560),
#   'region_gene_end': np.int64(101996926)},
#  '1_102433189_103371589': {'genes': ['COL11A1'],
#   'region_gene_start': np.int64(102876467),
#   'region_gene_end': np.int64(103108872)},
#  '1_103371589_105545220': {'genes': ['AMY2A', 'AMY2B', 'RNPC3'],
#   'region_gene_start': np.int64(103525691),
#   'region_gene_end': np.int64(103625780)},
#  '1_105545220_107867043': {'genes': ['NTNG1', 'PRMT6', 'VAV3'],
#   'region_gene_start': np.int64(107056674),
#   'region_gene_end': np.int64(107965180)},
#  '1_107867043_109761309': {'genes': ['AKNAD1',
#    'AMIGO1',
#    'AMPD2',
#    'ATXN7L2',
#    'C1orf194',
#    'CELSR2',
#    'CLCC1',
#    'CYB561D1',
#    'EPS8L3',
#    'FAM102B',
#    'FNDC7',
#    'GNAI3',
#    'GPR61',
#    'GPSM2',
#    'GSTM1',
#    'GSTM2',
#    'GSTM3',
#    'GSTM4',
#    'GSTM5',
#    'HENMT1',
#    'KIAA1324',
#    'MYBPHL',
#    'PRPF38B',
#    'PSMA5',
#    'PSRC1',
#    'SLC25A24',
#    'SORT1',
#    'STXBP3',
#    'SYPL2',
#    'TAF13',
#    'TMEM167B',
#    'VAV3',
#    'WDR47'],
#   'region_gene_start': np.int64(107571161),
#   'region_gene_end': np.int64(109775428)},
#  '1_109761309_111199115': {'genes': ['AHCYL1',
#    'ALX3',
#    'CD53',
#    'CEPT1',
#    'CSF1',
#    'DENND2D',
#    'DRAM2',
#    'EPS8L3',
#    'GSTM5',
#    'KCNA2',
#    'KCNA3',
#    'KCNC4',
#    'LAMTOR5',
#    'LRIF1',
#    'PROK1',
#    'RBM15',
#    'SLC16A4',
#    'SLC6A17',
#    'STRIP1'],
#   'region_gene_start': np.int64(109711780),
#   'region_gene_end': np.int64(111204535)},
#  '1_111199115_112730684': {'genes': ['ADORA3',
#    'C1orf162',
#    'CAPZA1',
#    'CHI3L2',
#    'CHIA',
#    'CTTNBP2NL',
#    'DDX20',
#    'DENND2D',
#    'KCND3',
#    'MOV10',
#    'OVGP1',
#    'PIFO',
#    'PPM1J',
#    'RAP1A',
#    'RHOC',
#    'ST7L',
#    'WDR77',
#    'WNT2B'],
#   'region_gene_start': np.int64(111185969),
#   'region_gene_end': np.int64(112715477)},
#  '1_112730684_114331223': {'genes': ['AP4B1',
#    'BCL2L15',
#    'DCLRE1B',
#    'HIPK1',
#    'LRIG2',
#    'MAGI3',
#    'OLFML3',
#    'PHTF1',
#    'PTPN22',
#    'RSBN1',
#    'SLC16A1',
#    'SYT6'],
#   'region_gene_start': np.int64(112911847),
#   'region_gene_end': np.int64(114153919)},
#  '1_114331223_115337972': {'genes': ['AMPD1',
#    'BCAS2',
#    'CSDE1',
#    'DENND2C',
#    'NGF',
#    'NRAS',
#    'SIKE1',
#    'SYCP1',
#    'TRIM33',
#    'TSPAN2'],
#   'region_gene_start': np.int64(114392790),
#   'region_gene_end': np.int64(115338249)},
#  '1_115337972_118296444': {'genes': ['ATP1A1',
#    'CASQ2',
#    'CD101',
#    'CD2',
#    'CD58',
#    'GDAP2',
#    'IGSF3',
#    'MAB21L3',
#    'MAN1A2',
#    'NGF',
#    'NHLH2',
#    'PTGFRN',
#    'SLC22A15',
#    'SPAG17',
#    'TRIM45',
#    'TTF2',
#    'VANGL1',
#    'VTCN1',
#    'WDR3'],
#   'region_gene_start': np.int64(115285917),
#   'region_gene_end': np.int64(118185228)},
#  '1_118296444_148907004': {'genes': ['AC245100.1',
#    'ACP6',
#    'ANKRD34A',
#    'ANKRD35',
#    'BCL9',
#    'CD160',
#    'CHD1L',
#    'FAM72B',
#    'FAM72C',
#    'FAM72D',
#    'FCGR1B',
#    'FMO5',
#    'GJA5',
#    'GPR89A',
#    'GPR89B',
#    'HAO2',
#    'HSD3B1',
#    'HSD3B2',
#    'ITGA10',
#    'LIX1L',
#    'NBPF10',
#    'NBPF11',
#    'NBPF12',
#    'NBPF14',
#    'NBPF15',
#    'NBPF26',
#    'NOTCH2',
#    'NUDT17',
#    'PDE4DIP',
#    'PDZK1',
#    'PEX11B',
#    'PHGDH',
#    'PIAS3',
#    'POLR3C',
#    'POLR3GL',
#    'PPIAL4G',
#    'PRKAB2',
#    'RBM8A',
#    'RNF115',
#    'SEC22B',
#    'SRGAP2B',
#    'SRGAP2C',
#    'TBX15',
#    'TXNIP',
#    'WARS2',
#    'ZNF697'],
#   'region_gene_start': np.int64(118883046),
#   'region_gene_end': np.int64(149048286)},
#  '1_151566405_153208353': {'genes': ['C2CD4D',
#    'CELF3',
#    'CRNN',
#    'FLG',
#    'FLG2',
#    'HRNR',
#    'OAZ3',
#    'RIIAD1',
#    'RORC',
#    'S100A10',
#    'S100A11',
#    'SNX27',
#    'TCHH',
#    'TDRKH',
#    'THEM4',
#    'THEM5',
#    'TUFT1'],
#   'region_gene_start': np.int64(151540305),
#   'region_gene_end': np.int64(152414263)},
#  '1_153208353_154797927': {'genes': ['ADAR',
#    'AQP10',
#    'ATP8B2',
#    'C1orf189',
#    'C1orf43',
#    'CHRNB2',
#    'CHTOP',
#    'CREB3L4',
#    'CRTC2',
#    'DENND4B',
#    'GATAD2B',
#    'HAX1',
#    'IL6R',
#    'ILF2',
#    'INTS3',
#    'JTB',
#    'KCNN3',
#    'NPR1',
#    'NUP210L',
#    'RAB13',
#    'S100A1',
#    'S100A12',
#    'S100A13',
#    'S100A14',
#    'S100A16',
#    'S100A2',
#    'S100A4',
#    'S100A5',
#    'S100A6',
#    'S100A7',
#    'S100A8',
#    'S100A9',
#    'SHE',
#    'SLC27A3',
#    'SLC39A1',
#    'SNAPIN',
#    'TDRD10',
#    'TPM3',
#    'UBAP2L',
#    'UBE2Q1'],
#   'region_gene_start': np.int64(153357854),
#   'region_gene_end': np.int64(154870281)},
#  '1_154797927_156366342': {'genes': ['AC234582.1',
#    'AC234582.2',
#    'ADAM15',
#    'ARHGEF2',
#    'ASH1L',
#    'BGLAP',
#    'CCT3',
#    'CKS1B',
#    'CLK2',
#    'DCST1',
#    'DCST2',
#    'DPM3',
#    'EFNA1',
#    'EFNA3',
#    'EFNA4',
#    'FAM189B',
#    'FDPS',
#    'FLAD1',
#    'GBA',
#    'GLMP',
#    'GON4L',
#    'HCN3',
#    'KCNN3',
#    'KRTCAP2',
#    'LAMTOR2',
#    'LMNA',
#    'MEX3A',
#    'MSTO1',
#    'MTX1',
#    'MUC1',
#    'PAQR6',
#    'PBXIP1',
#    'PKLR',
#    'PMF1',
#    'PMVK',
#    'PYGO2',
#    'RAB25',
#    'RIT1',
#    'RUSC1',
#    'SCAMP3',
#    'SEMA4A',
#    'SHC1',
#    'SLC25A44',
#    'SLC50A1',
#    'SMG5',
#    'SSR2',
#    'SYT11',
#    'THBS3',
#    'TMEM79',
#    'TRIM46',
#    'TSACC',
#    'UBQLN4',
#    'YY1AP1',
#    'ZBTB7B'],
#   'region_gene_start': np.int64(154697455),
#   'region_gene_end': np.int64(156367873)},
#  '1_156366342_158057622': {'genes': ['AL365181.2',
#    'ARHGEF11',
#    'BCAN',
#    'C1orf61',
#    'CCT3',
#    'CD5L',
#    'CRABP2',
#    'ETV3',
#    'ETV3L',
#    'FCRL1',
#    'FCRL2',
#    'GPATCH4',
#    'HAPLN2',
#    'HDGF',
#    'INSRR',
#    'IQGAP3',
#    'ISG20L2',
#    'LRRC71',
#    'MEF2D',
#    'NES',
#    'NTRK1',
#    'PEAR1',
#    'PRCC',
#    'RHBG',
#    'RRNAD1',
#    'SH2D2A',
#    'TTC24'],
#   'region_gene_start': np.int64(156308968),
#   'region_gene_end': np.int64(157898256)},
#  '1_158057622_159943258': {'genes': ['ACKR1',
#    'AIM2',
#    'CADM3',
#    'CD1D',
#    'CFAP45',
#    'DUSP23',
#    'FCRL6',
#    'IFI16',
#    'IGSF9',
#    'MNDA',
#    'OR10K1',
#    'OR10R2',
#    'PYHIN1',
#    'SLAMF8',
#    'TAGLN2',
#    'VSIG8'],
#   'region_gene_start': np.int64(158178030),
#   'region_gene_end': np.int64(159945613)},
#  '1_159943258_162376931': {'genes': ['ADAMTS4',
#    'ARHGAP30',
#    'ATF6',
#    'ATP1A2',
#    'ATP1A4',
#    'B4GALT3',
#    'CASQ1',
#    'CD244',
#    'CD48',
#    'CD84',
#    'CFAP126',
#    'COPA',
#    'DCAF8',
#    'DEDD',
#    'DUSP12',
#    'F11R',
#    'FCER1G',
#    'FCGR2A',
#    'FCGR2B',
#    'FCGR3A',
#    'FCGR3B',
#    'FCRLA',
#    'FCRLB',
#    'HSPA6',
#    'IGSF8',
#    'IGSF9',
#    'KCNJ10',
#    'KCNJ9',
#    'KLHDC9',
#    'LY9',
#    'MPZ',
#    'NCSTN',
#    'NDUFS2',
#    'NHLH1',
#    'NIT1',
#    'NOS1AP',
#    'NR1I3',
#    'OLFML2B',
#    'PCP4L1',
#    'PEA15',
#    'PEX19',
#    'PFDN2',
#    'PIGM',
#    'PPOX',
#    'SDHC',
#    'SLAMF6',
#    'SLAMF7',
#    'TOMM40L',
#    'TSTD1',
#    'UFC1',
#    'USF1',
#    'USP21',
#    'VANGL2'],
#   'region_gene_start': np.int64(159927039),
#   'region_gene_end': np.int64(162370475)},
#  '1_162376931_165222465': {'genes': ['C1orf226',
#    'DDR2',
#    'HSD17B7',
#    'LMX1A',
#    'NUF2',
#    'PBX1',
#    'RGS4',
#    'RGS5',
#    'SH2D1B',
#    'UAP1',
#    'UHMK1'],
#   'region_gene_start': np.int64(162378841),
#   'region_gene_end': np.int64(165356715)},
#  '1_165222465_166491280': {'genes': ['ALDH9A1',
#    'FAM78B',
#    'LMX1A',
#    'LRRC52',
#    'MGST3',
#    'RXRG',
#    'TMCO1',
#    'UCK2'],
#   'region_gene_start': np.int64(165201867),
#   'region_gene_end': np.int64(166167001)},
#  '1_166491280_169117086': {'genes': ['ADCY10',
#    'ATP1B1',
#    'CD247',
#    'CREG1',
#    'DCAF6',
#    'DPT',
#    'DUSP27',
#    'GPA33',
#    'GPR161',
#    'ILDR2',
#    'MAEL',
#    'MPC2',
#    'MPZL1',
#    'POGK',
#    'POU2F1',
#    'RCSD1',
#    'SFT2D2',
#    'TADA1',
#    'TBX19',
#    'TIPRL',
#    'XCL1'],
#   'region_gene_start': np.int64(166839447),
#   'region_gene_end': np.int64(169132722)},
#  '1_169117086_170588635': {'genes': ['ATP1B1',
#    'BLZF1',
#    'C1orf112',
#    'CCDC181',
#    'F5',
#    'GORAB',
#    'KIFAP3',
#    'METTL11B',
#    'METTL18',
#    'NME7',
#    'SCYL3',
#    'SELE',
#    'SELL',
#    'SELP',
#    'SLC19A2'],
#   'region_gene_start': np.int64(169105697),
#   'region_gene_end': np.int64(170553446)},
#  '1_170588635_173128768': {'genes': ['C1orf105',
#    'DNM3',
#    'FMO1',
#    'FMO2',
#    'FMO3',
#    'FMO4',
#    'MROH9',
#    'MYOC',
#    'PIGC',
#    'PRRC2C',
#    'PRRX1',
#    'SUCO',
#    'TNFSF18',
#    'VAMP4'],
#   'region_gene_start': np.int64(170662728),
#   'region_gene_end': np.int64(173050963)},
#  '1_173128768_175120632': {'genes': ['ANKRD45',
#    'CACYBP',
#    'CENPL',
#    'DARS2',
#    'GPR52',
#    'KLHL20',
#    'PRDX6',
#    'RABGAP1L',
#    'RC3H1',
#    'SERPINC1',
#    'SLC9C2',
#    'TNFSF4',
#    'TNN',
#    'ZBTB37'],
#   'region_gene_start': np.int64(173183731),
#   'region_gene_end': np.int64(175148075)},
#  '1_175120632_177464245': {'genes': ['ASTN1',
#    'BRINP2',
#    'KIAA0040',
#    'PAPPA2',
#    'TNN',
#    'TNR'],
#   'region_gene_start': np.int64(175067833),
#   'region_gene_end': np.int64(177282422)},
#  '1_177464245_178975174': {'genes': ['ANGPTL1',
#    'RALGPS2',
#    'RASAL2',
#    'SEC16B',
#    'TEX35'],
#   'region_gene_start': np.int64(177923956),
#   'region_gene_end': np.int64(178921841)},
#  '1_178975174_178985335': {'genes': [],
#   'region_gene_start': None,
#   'region_gene_end': None},
#  '1_178985335_181174985': {'genes': ['ABL2',
#    'AXDND1',
#    'CEP350',
#    'FAM163A',
#    'FAM20B',
#    'IER5',
#    'KIAA1614',
#    'LHX4',
#    'MR1',
#    'NPHS2',
#    'QSOX1',
#    'SOAT1',
#    'STX6',
#    'TDRD5',
#    'TOR1AIP1',
#    'TOR1AIP2',
#    'TOR3A',
#    'XPR1'],
#   'region_gene_start': np.int64(179025804),
#   'region_gene_end': np.int64(181092900)},
#  '1_181174985_182786221': {'genes': ['CACNA1E',
#    'GLUL',
#    'RGS16',
#    'RGS8',
#    'RGSL1',
#    'RNASEL',
#    'TEDDM1',
#    'ZNF648'],
#   'region_gene_start': np.int64(181317690),
#   'region_gene_end': np.int64(182684576)},
#  '1_182786221_184626379': {'genes': ['APOBEC4',
#    'ARPC5',
#    'C1orf21',
#    'COLGALT2',
#    'DHX9',
#    'LAMC1',
#    'LAMC2',
#    'NCF2',
#    'NMNAT2',
#    'NPL',
#    'RGL1',
#    'SHCBP1L',
#    'SMG7',
#    'TSEN15'],
#   'region_gene_start': np.int64(182789293),
#   'region_gene_end': np.int64(184629019)},
#  '1_184626379_186840891': {'genes': ['C1orf21',
#    'EDEM3',
#    'HMCN1',
#    'IVNS1ABP',
#    'PDC',
#    'PLA2G4A',
#    'PRG4',
#    'PTGS2',
#    'RNF2',
#    'SWT1',
#    'TPR',
#    'TRMT1L'],
#   'region_gene_start': np.int64(184387029),
#   'region_gene_end': np.int64(186988981)},
#  '1_186840891_188790814': {'genes': ['PLA2G4A'],
#   'region_gene_start': np.int64(186828949),
#   'region_gene_end': np.int64(186988981)},
#  '1_188790814_189935000': {'genes': [],
#   'region_gene_start': None,
#   'region_gene_end': None},
#  '1_189935000_191899800': {'genes': ['BRINP3'],
#   'region_gene_start': np.int64(190097658),
#   'region_gene_end': np.int64(190478404)},
#  '1_191899800_194138312': {'genes': ['B3GALT2',
#    'CDC73',
#    'GLRX2',
#    'RGS1',
#    'RGS13',
#    'RGS18',
#    'RGS2',
#    'RGS21',
#    'UCHL5'],
#   'region_gene_start': np.int64(192158462),
#   'region_gene_end': np.int64(193254815)},
#  '1_194138312_196207071': {'genes': [],
#   'region_gene_start': None,
#   'region_gene_end': None},
#  '1_196207071_197342384': {'genes': ['ASPM',
#    'CFH',
#    'CFHR1',
#    'CFHR2',
#    'CFHR3',
#    'CFHR4',
#    'CFHR5',
#    'CRB1',
#    'KCNT2',
#    'ZBTB41'],
#   'region_gene_start': np.int64(196225779),
#   'region_gene_end': np.int64(197478455)},
#  '1_197342384_199270756': {'genes': ['ATP6V1G3',
#    'C1orf53',
#    'CRB1',
#    'DENND1B',
#    'NEK7',
#    'PTPRC'],
#   'region_gene_start': np.int64(197268204),
#   'region_gene_end': np.int64(198757476)},
#  '1_199270756_200168521': {'genes': ['NR5A2'],
#   'region_gene_start': np.int64(200027614),
#   'region_gene_end': np.int64(200177420)},
#  '1_200168521_201620847': {'genes': ['ASCL5',
#    'CACNA1S',
#    'CAMSAP2',
#    'CSRP1',
#    'DDX59',
#    'IGFN1',
#    'KIF14',
#    'KIF21B',
#    'NR5A2',
#    'PHLDA3',
#    'PKP1',
#    'TMEM9',
#    'TNNI1',
#    'TNNT2',
#    'ZNF281'],
#   'region_gene_start': np.int64(200027614),
#   'region_gene_end': np.int64(201509456)},
#  '1_201620847_203365606': {'genes': ['ADIPOR1',
#    'ADORA1',
#    'ARL8A',
#    'BTG2',
#    'CHI3L1',
#    'CHIT1',
#    'CYB5R1',
#    'ELF3',
#    'FMOD',
#    'GPR37L1',
#    'IPO9',
#    'KDM5B',
#    'KLHL12',
#    'LGR6',
#    'LMOD1',
#    'MYBPH',
#    'MYOG',
#    'NAV1',
#    'PPFIA4',
#    'PPP1R12B',
#    'PTPN7',
#    'RABIF',
#    'RNPEP',
#    'SHISA4',
#    'SYT2',
#    'TIMM17A',
#    'TMEM183A',
#    'UBE2T'],
#   'region_gene_start': np.int64(201622885),
#   'region_gene_end': np.int64(203351758)},
#  '1_203365606_204711940': {'genes': ['ATP2B4',
#    'ETNK2',
#    'GOLT1A',
#    'KISS1',
#    'LAX1',
#    'LRRN2',
#    'MDM4',
#    'OPTC',
#    'PIK3C2B',
#    'PLEKHA6',
#    'PPP1R15B',
#    'PRELP',
#    'REN',
#    'SNRPE',
#    'SOX13',
#    'ZBED6',
#    'ZC3H11A'],
#   'region_gene_start': np.int64(203475806),
#   'region_gene_end': np.int64(204685738)},
#  '1_204711940_206268085': {'genes': ['AVPR1B',
#    'CDK18',
#    'CNTN2',
#    'CTSE',
#    'DSTYK',
#    'ELK4',
#    'FAM72A',
#    'KLHDC8A',
#    'LEMD1',
#    'NFASC',
#    'NUAK2',
#    'NUCKS1',
#    'PM20D1',
#    'RAB29',
#    'RAB7B',
#    'RBBP5',
#    'SLC26A9',
#    'SLC41A1',
#    'SLC45A3',
#    'SRGAP2',
#    'TMCC2',
#    'TMEM81'],
#   'region_gene_start': np.int64(204828651),
#   'region_gene_end': np.int64(206464443)},
#  '1_206268085_208237019': {'genes': ['C1orf116',
#    'C4BPA',
#    'C4BPB',
#    'CD34',
#    'CD46',
#    'CD55',
#    'CR1',
#    'CR1L',
#    'CR2',
#    'DYRK3',
#    'EIF2D',
#    'FCAMR',
#    'IKBKE',
#    'IL10',
#    'IL19',
#    'MAPKAPK2',
#    'PFKFB2',
#    'PIGR',
#    'PLXNA2',
#    'RASSF5',
#    'SRGAP2',
#    'YOD1'],
#   'region_gene_start': np.int64(206203345),
#   'region_gene_end': np.int64(208244384)},
#  '1_208237019_210614406': {'genes': ['C1orf74',
#    'CAMK1G',
#    'G0S2',
#    'HHAT',
#    'HSD11B1',
#    'IRF6',
#    'LAMB3',
#    'PLXNA2',
#    'SERTAD4',
#    'SYT14',
#    'TRAF3IP3'],
#   'region_gene_start': np.int64(208022242),
#   'region_gene_end': np.int64(210676296)},
#  '1_210614406_212668988': {'genes': ['ATF3',
#    'DTL',
#    'HHAT',
#    'INTS7',
#    'KCNH1',
#    'LPGAT1',
#    'NEK2',
#    'NENF',
#    'PPP2R5A',
#    'RCOR3',
#    'RD3',
#    'SLC30A1',
#    'TRAF5'],
#   'region_gene_start': np.int64(210328252),
#   'region_gene_end': np.int64(212620777)},
#  '1_212668988_214404923': {'genes': ['ANGEL2',
#    'BATF3',
#    'FLVCR1',
#    'NSL1',
#    'PROX1',
#    'PTPN14',
#    'RPS6KC1',
#    'SMYD2',
#    'SPATA45',
#    'TATDN3',
#    'VASH2'],
#   'region_gene_start': np.int64(212686417),
#   'region_gene_end': np.int64(214552449)},
#  '1_214404923_216070292': {'genes': ['CENPF',
#    'KCNK2',
#    'KCTD3',
#    'PTPN14',
#    'USH2A'],
#   'region_gene_start': np.int64(214348700),
#   'region_gene_end': np.int64(216423448)},
#  '1_216070292_218532171': {'genes': ['ESRRG',
#    'GPATCH2',
#    'RRP15',
#    'SPATA17',
#    'TGFB2',
#    'USH2A'],
#   'region_gene_start': np.int64(215622891),
#   'region_gene_end': np.int64(218444619)},
#  '1_218532171_219417229': {'genes': ['LYPLAL1'],
#   'region_gene_start': np.int64(219173869),
#   'region_gene_end': np.int64(219212865)},
#  '1_219417229_221684889': {'genes': ['BPNT1',
#    'C1orf115',
#    'HLX',
#    'IARS2',
#    'MARK1',
#    'RAB3GAP2',
#    'SLC30A10'],
#   'region_gene_start': np.int64(219685427),
#   'region_gene_end': np.int64(220885059)},
#  '1_221684889_222056878': {'genes': ['DUSP10'],
#   'region_gene_start': np.int64(221701424),
#   'region_gene_end': np.int64(221742089)},
#  '1_222056878_224750818': {'genes': ['AIDA',
#    'BROX',
#    'CAPN2',
#    'CAPN8',
#    'CNIH3',
#    'CNIH4',
#    'DEGS1',
#    'DISP1',
#    'FAM177B',
#    'FBXO28',
#    'HHIPL2',
#    'MIA3',
#    'NVL',
#    'SUSD4',
#    'TAF1A',
#    'TLR5',
#    'TP53BP2',
#    'WDR26'],
#   'region_gene_start': np.int64(222522258),
#   'region_gene_end': np.int64(224740554)},
#  '1_224750818_226623159': {'genes': ['ACBD3',
#    'DNAH14',
#    'ENAH',
#    'EPHX1',
#    'LBR',
#    'LEFTY1',
#    'LEFTY2',
#    'LIN9',
#    'MIXL1',
#    'PARP1',
#    'PYCR2',
#    'SDE2',
#    'SRP9',
#    'TMEM63A'],
#   'region_gene_start': np.int64(224896262),
#   'region_gene_end': np.int64(226408093)},
#  '1_226623159_229020501': {'genes': ['ARF1',
#    'C1orf35',
#    'CDC42BPA',
#    'GJC2',
#    'GUK1',
#    'IBA57',
#    'ITPKB',
#    'JMJD4',
#    'OBSCN',
#    'PRSS38',
#    'PSEN2',
#    'RHOU',
#    'RNF187',
#    'SNAP47',
#    'TRIM11',
#    'TRIM17',
#    'WNT3A',
#    'WNT9A',
#    'ZNF678'],
#   'region_gene_start': np.int64(226631690),
#   'region_gene_end': np.int64(228746664)},
#  '1_229020501_230549509': {'genes': ['ABCB10',
#    'ACTA1',
#    'CCSAP',
#    'GALNT2',
#    'NUP133',
#    'PGBD5',
#    'RAB4A',
#    'TAF5L',
#    'TMEM78',
#    'URB2'],
#   'region_gene_start': np.int64(229249636),
#   'region_gene_end': np.int64(230426332)},
#  '1_230549509_231954506': {'genes': ['AGT',
#    'ARV1',
#    'C1orf131',
#    'C1orf198',
#    'CAPN9',
#    'COG2',
#    'DISC1',
#    'EGLN1',
#    'EXOC8',
#    'FAM89A',
#    'GNPAT',
#    'SPRTN',
#    'TRIM67',
#    'TSNAX',
#    'TTC13'],
#   'region_gene_start': np.int64(230642481),
#   'region_gene_end': np.int64(232041272)},
#  '1_231954506_233293538': {'genes': ['DISC1', 'MAP10', 'NTPCR', 'SIPA1L2'],
#   'region_gene_start': np.int64(231626790),
#   'region_gene_end': np.int64(232983882)},
#  '1_233293538_234463688': {'genes': ['COA6', 'KCNK1', 'SLC35F3', 'TARBP1'],
#   'region_gene_start': np.int64(233614106),
#   'region_gene_end': np.int64(234479179)},
#  '1_234463688_235656136': {'genes': ['ARID4B',
#    'B3GALNT2',
#    'GGPS1',
#    'GNG4',
#    'IRF2BP2',
#    'RBM34',
#    'TARBP1',
#    'TBCE',
#    'TBCE',
#    'TOMM20'],
#   'region_gene_start': np.int64(234391313),
#   'region_gene_end': np.int64(235650754)},
#  '1_235656136_237392328': {'genes': ['ACTN2',
#    'EDARADD',
#    'GPR137B',
#    'HEATR1',
#    'LGALS8',
#    'LYST',
#    'MTR',
#    'NID1',
#    'RYR2'],
#   'region_gene_start': np.int64(235661041),
#   'region_gene_end': np.int64(237833988)},
#  '1_237392328_238404507': {'genes': ['MTRNR2L11', 'RYR2'],
#   'region_gene_start': np.int64(237042184),
#   'region_gene_end': np.int64(237945275)},
#  '1_238404507_239762014': {'genes': ['CHRM3'],
#   'region_gene_start': np.int64(239386565),
#   'region_gene_end': np.int64(239915452)},
#  '1_239762014_240400791': {'genes': ['CHRM3', 'FMN2'],
#   'region_gene_start': np.int64(239386565),
#   'region_gene_end': np.int64(240475187)},
#  '1_240400791_241418920': {'genes': ['FMN2', 'GREM2', 'RGS7'],
#   'region_gene_start': np.int64(240014348),
#   'region_gene_end': np.int64(241357230)},
#  '1_241418920_241908300': {'genes': ['CHML',
#    'EXO1',
#    'FH',
#    'KMO',
#    'OPN3',
#    'WDR64'],
#   'region_gene_start': np.int64(241497603),
#   'region_gene_end': np.int64(241895148)},
#  '1_241908300_243946197': {'genes': ['AKT3',
#    'CEP170',
#    'MAP1LC3C',
#    'PLD5',
#    'SDCCAG8'],
#   'region_gene_start': np.int64(241995490),
#   'region_gene_end': np.int64(243851079)},
#  '1_243946197_245343444': {'genes': ['C1orf100',
#    'COX20',
#    'DESI2',
#    'EFCAB2',
#    'HNRNPU',
#    'KIF26B',
#    'ZBTB18'],
#   'region_gene_start': np.int64(244048939),
#   'region_gene_end': np.int64(245709432)},
#  '1_245343444_247181216': {'genes': ['AHCTF1',
#    'CNST',
#    'KIF26B',
#    'SCCPDH',
#    'SMYD3',
#    'TFB2M',
#    'ZNF124',
#    'ZNF669',
#    'ZNF670',
#    'ZNF695'],
#   'region_gene_start': np.int64(245154985),
#   'region_gene_end': np.int64(247172016)},
#  '1_247181216_248945267': {'genes': ['GCSAML',
#    'LYPD8',
#    'NLRP3',
#    'OR13G1',
#    'OR14A16',
#    'OR14I1',
#    'OR2AJ1',
#    'OR2AK2',
#    'OR2B11',
#    'OR2G6',
#    'OR2L13',
#    'OR2L2',
#    'OR2L3',
#    'OR2L5',
#    'OR2L8',
#    'OR2M2',
#    'OR2M3',
#    'OR2M4',
#    'OR2T1',
#    'OR2T10',
#    'OR2T12',
#    'OR2T2',
#    'OR2T27',
#    'OR2T29',
#    'OR2T33',
#    'OR2T6',
#    'OR2T8',
#    'OR6F1',
#    'PGBD2',
#    'SH3BP5L',
#    'TRIM58',
#    'ZNF496',
#    'ZNF672',
#    'ZNF692'],
#   'region_gene_start': np.int64(247297412),
#   'region_gene_end': np.int64(248919946)},
#  '2_10133_1777250': {'genes': ['AC092159.1',
#    'ACP1',
#    'FAM110C',
#    'PXDN',
#    'SH3YL1',
#    'SNTG2',
#    'TMEM18',
#    'TPO'],
#   'region_gene_start': np.int64(38814),
#   'region_gene_end': np.int64(1744852)},
#  '2_1777250_3926189': {'genes': ['ADI1',
#    'ALLC',
#    'COLEC11',
#    'DCDC2C',
#    'MYT1L',
#    'RNASEH1',
#    'TRAPPC12'],
#   'region_gene_start': np.int64(1789113),
#   'region_gene_end': np.int64(3848008)},
#  '2_3926189_5568205': {'genes': [],
#   'region_gene_start': None,
#   'region_gene_end': None},
#  '2_5568205_6696122': {'genes': ['SOX11'],
#   'region_gene_start': np.int64(5692384),
#   'region_gene_end': np.int64(5701385)},
#  '2_6696122_8282017': {'genes': ['CMPK2', 'RNF144A', 'RSAD2'],
#   'region_gene_start': np.int64(6840570),
#   'region_gene_end': np.int64(7068286)},
#  '2_8282017_10158342': {'genes': ['ADAM17',
#    'ASAP2',
#    'CPSF3',
#    'CYS1',
#    'GRHL1',
#    'IAH1',
#    'ID2',
#    'ITGB1BP1',
#    'KIDINS220',
#    'KLF11',
#    'MBOAT2',
#    'RRM2',
#    'TAF1B',
#    'YWHAQ'],
#   'region_gene_start': np.int64(8678845),
#   'region_gene_end': np.int64(10211725)},
#  '2_10158342_12279024': {'genes': ['ATP6V1C2',
#    'C2orf50',
#    'E2F6',
#    'GREB1',
#    'HPCAL1',
#    'KCNF1',
#    'LPIN1',
#    'NOL10',
#    'NTSR2',
#    'ODC1',
#    'PDIA6',
#    'ROCK2',
#    'RRM2'],
#   'region_gene_start': np.int64(10120698),
#   'region_gene_end': np.int64(11827409)},
#  '2_12279024_14195184': {'genes': ['TRIB2'],
#   'region_gene_start': np.int64(12716889),
#   'region_gene_end': np.int64(12742734)},
#  '2_14195184_16148467': {'genes': ['DDX1', 'MYCN', 'NBAS'],
#   'region_gene_start': np.int64(15166914),
#   'region_gene_end': np.int64(15947007)},
#  '2_16148467_18466157': {'genes': ['GEN1',
#    'KCNS3',
#    'MSGN1',
#    'RAD51AP2',
#    'SMC6',
#    'VSNL1'],
#   'region_gene_start': np.int64(17510584),
#   'region_gene_end': np.int64(18361616)},
#  '2_18466157_19492643': {'genes': ['NT5C1B', 'OSR1', 'RDH14'],
#   'region_gene_start': np.int64(18554723),
#   'region_gene_end': np.int64(19358623)},
#  '2_19492643_20850730': {'genes': ['GDF7',
#    'HS1BP3',
#    'LAPTM4A',
#    'MATN3',
#    'PUM2',
#    'RHOB',
#    'SDC1',
#    'TTC32',
#    'WDR35'],
#   'region_gene_start': np.int64(19896631),
#   'region_gene_end': np.int64(20679243)},
#  '2_20850730_23118512': {'genes': ['APOB', 'TDRD15'],
#   'region_gene_start': np.int64(21001429),
#   'region_gene_end': np.int64(21144368)},
#  '2_23118512_24464049': {'genes': ['ATAD2B',
#    'FAM228A',
#    'FAM228B',
#    'FKBP1B',
#    'ITSN2',
#    'KLHL29',
#    'MFSD2B',
#    'PFN4',
#    'SF3B6',
#    'TP53I3',
#    'UBXN2A'],
#   'region_gene_start': np.int64(23385179),
#   'region_gene_end': np.int64(24360714)},
#  '2_24464049_26672117': {'genes': ['ADCY3',
#    'ASXL2',
#    'CENPO',
#    'CIB4',
#    'DNAJC27',
#    'DNMT3A',
#    'DRC1',
#    'DTNB',
#    'EFR3B',
#    'HADHA',
#    'HADHB',
#    'KIF3C',
#    'NCOA1',
#    'OTOF',
#    'POMC',
#    'PTRHD1',
#    'RAB10'],
#   'region_gene_start': np.int64(24491914),
#   'region_gene_end': np.int64(26641366)},
#  '2_26672117_28375910': {'genes': ['ABHD1',
#    'AGBL5',
#    'ATRAID',
#    'C2orf16',
#    'CAD',
#    'CCDC121',
#    'CENPA',
#    'CGREF1',
#    'DNAJC5G',
#    'DPYSL5',
#    'EIF2B4',
#    'EMILIN1',
#    'FNDC4',
#    'GCKR',
#    'GPN1',
#    'GTF3C2',
#    'IFT172',
#    'KCNK3',
#    'KHK',
#    'KRTCAP3',
#    'MAPRE3',
#    'MPV17',
#    'NRBP1',
#    'OST4',
#    'PPM1G',
#    'PREB',
#    'RBKS',
#    'SLC30A3',
#    'SLC35F6',
#    'SLC4A1AP',
#    'SLC5A6',
#    'SNX17',
#    'SUPT7L',
#    'TCF23',
#    'TMEM214',
#    'TRIM54',
#    'UCN',
#    'ZNF512',
#    'ZNF513'],
#   'region_gene_start': np.int64(26692690),
#   'region_gene_end': np.int64(27890681)},
#  '2_28375910_28994693': {'genes': ['FOSL2',
#    'PLB1',
#    'PPP1CB',
#    'SPDYA',
#    'TRMT61B',
#    'WDR43'],
#   'region_gene_start': np.int64(28392448),
#   'region_gene_end': np.int64(28948219)},
#  '2_28994693_30240845': {'genes': ['ALK', 'CLIP4', 'LBH', 'YPEL5'],
#   'region_gene_start': np.int64(29097705),
#   'region_gene_end': np.int64(30323730)},
#  '2_30240845_31327584': {'genes': ['CAPN13',
#    'CAPN14',
#    'EHD3',
#    'GALNT14',
#    'LBH',
#    'LCLAT1'],
#   'region_gene_start': np.int64(30231534),
#   'region_gene_end': np.int64(31269451)},
#  '2_31327584_33138710': {'genes': ['BIRC6',
#    'DPY30',
#    'LTBP1',
#    'MEMO1',
#    'NLRC4',
#    'SLC30A6',
#    'SPAST',
#    'SRD5A2',
#    'TTC27',
#    'XDH',
#    'YIPF4'],
#   'region_gene_start': np.int64(31334321),
#   'region_gene_end': np.int64(33399509)},
#  '2_33138710_35119962': {'genes': ['FAM98A', 'LTBP1', 'RASGRP3'],
#   'region_gene_start': np.int64(32946953),
#   'region_gene_end': np.int64(33599382)},
#  '2_35119962_35896940': {'genes': [],
#   'region_gene_start': None,
#   'region_gene_end': None},
#  '2_35896940_37905569': {'genes': ['CDC42EP3',
#    'CEBPZ',
#    'CEBPZOS',
#    'CRIM1',
#    'EIF2AK2',
#    'FEZ2',
#    'GPATCH11',
#    'HEATR5B',
#    'NDUFAF7',
#    'PRKD3',
#    'QPCT',
#    'STRN',
#    'SULT6B1',
#    'VIT'],
#   'region_gene_start': np.int64(36355778),
#   'region_gene_end': np.int64(37738468)},
#  '2_37905569_38804195': {'genes': ['ATL2',
#    'CYP1B1',
#    'DHX57',
#    'GALM',
#    'GEMIN6',
#    'HNRNPLL',
#    'RMDN2',
#    'SRSF7'],
#   'region_gene_start': np.int64(37923187),
#   'region_gene_end': np.int64(38875934)},
#  '2_38804195_40054343': {'genes': ['ARHGEF33',
#    'CDKL4',
#    'DHX57',
#    'MAP4K3',
#    'MORN2',
#    'SOS1',
#    'THUMPD2',
#    'TMEM178A'],
#   'region_gene_start': np.int64(38797729),
#   'region_gene_end': np.int64(39779267)},
#  '2_40054343_43082452': {'genes': ['C2orf91',
#    'COX7A2L',
#    'EML4',
#    'HAAO',
#    'KCNG3',
#    'MTA3',
#    'OXER1',
#    'PKDCC',
#    'SLC8A1'],
#   'region_gene_start': np.int64(40097270),
#   'region_gene_end': np.int64(42792593)},
#  '2_43082452_44086664': {'genes': ['ABCG5',
#    'ABCG8',
#    'DYNC2LI1',
#    'LRPPRC',
#    'PLEKHH2',
#    'THADA',
#    'ZFP36L2'],
#   'region_gene_start': np.int64(43222402),
#   'region_gene_end': np.int64(43995989)},
#  '2_44086664_46255495': {'genes': ['CAMKMT',
#    'PPM1B',
#    'PREPL',
#    'PRKCE',
#    'SIX3',
#    'SLC3A1',
#    'SRBD1'],
#   'region_gene_start': np.int64(44167969),
#   'region_gene_end': np.int64(46187990)},
#  '2_46255495_47091633': {'genes': ['ATP6V1E2',
#    'CRIPT',
#    'EPAS1',
#    'MCFD2',
#    'PIGF',
#    'RHOQ',
#    'SOCS5',
#    'TMEM247',
#    'TTC7A'],
#   'region_gene_start': np.int64(46293667),
#   'region_gene_end': np.int64(47076137)},
#  '2_47091633_47985862': {'genes': ['CALM2',
#    'EPCAM',
#    'FBXO11',
#    'KCNK12',
#    'MSH2',
#    'MSH6'],
#   'region_gene_start': np.int64(47160083),
#   'region_gene_end': np.int64(47906498)},
#  '2_47985862_49795119': {'genes': ['FOXN2',
#    'FSHR',
#    'LHCGR',
#    'PPP1R21',
#    'STON1',
#    'STON1-GTF2A1L'],
#   'region_gene_start': np.int64(48314637),
#   'region_gene_end': np.int64(49154527)},
#  '2_49795119_50591790': {'genes': ['NRXN1'],
#   'region_gene_start': np.int64(49918503),
#   'region_gene_end': np.int64(51225575)},
#  '2_50591790_52263995': {'genes': ['NRXN1'],
#   'region_gene_start': np.int64(49918503),
#   'region_gene_end': np.int64(51225575)},
#  '2_52263995_53281314': {'genes': [],
#   'region_gene_start': None,
#   'region_gene_end': None},
#  '2_53281314_54458089': {'genes': ['ACYP2',
#    'C2orf73',
#    'CHAC2',
#    'ERLEC1',
#    'GPR75',
#    'PSME4',
#    'SPTBN1',
#    'TSPYL6'],
#   'region_gene_start': np.int64(53767804),
#   'region_gene_end': np.int64(54671446)},
#  '2_54458089_55976210': {'genes': ['CCDC88A',
#    'CFAP36',
#    'CLHC1',
#    'EFEMP1',
#    'EML6',
#    'MTIF2',
#    'PNPT1',
#    'RTN4',
#    'SPTBN1'],
#   'region_gene_start': np.int64(54456317),
#   'region_gene_end': np.int64(55924139)},
#  '2_55976210_57201965': {'genes': ['CCDC85A'],
#   'region_gene_start': np.int64(56183990),
#   'region_gene_end': np.int64(56386172)},
#  '2_57201965_58070180': {'genes': ['VRK2'],
#   'region_gene_start': np.int64(57907629),
#   'region_gene_end': np.int64(58159920)},
#  '2_58070180_60064865': {'genes': ['FANCL', 'VRK2'],
#   'region_gene_start': np.int64(57907629),
#   'region_gene_end': np.int64(58241372)},
#  '2_60064865_62201909': {'genes': ['B3GNT2',
#    'BCL11A',
#    'C2orf74',
#    'CCT4',
#    'COMMD1',
#    'FAM161A',
#    'KIAA1841',
#    'PAPOLG',
#    'PEX13',
#    'PUS10',
#    'REL',
#    'USP34',
#    'XPO1'],
#   'region_gene_start': np.int64(60450520),
#   'region_gene_end': np.int64(62224731)},
#  '2_62201909_64398779': {'genes': ['B3GNT2',
#    'EHBP1',
#    'MDH1',
#    'OTX1',
#    'PELI1',
#    'TMEM17',
#    'UGP2',
#    'VPS54',
#    'WDPCP'],
#   'region_gene_start': np.int64(62196115),
#   'region_gene_end': np.int64(64144420)},
#  '2_64398779_65706310': {'genes': ['ACTR2',
#    'AFTPH',
#    'CEP68',
#    'LGALSL',
#    'RAB1A',
#    'SERTAD2',
#    'SLC1A4',
#    'SPRED2'],
#   'region_gene_start': np.int64(64453969),
#   'region_gene_end': np.int64(65432637)},
#  '2_65706310_66999034': {'genes': ['MEIS1'],
#   'region_gene_start': np.int64(66433452),
#   'region_gene_end': np.int64(66573869)},
#  '2_66999034_67783044': {'genes': ['ETAA1'],
#   'region_gene_start': np.int64(67397322),
#   'region_gene_end': np.int64(67412089)},
#  '2_67783044_68912432': {'genes': ['APLF',
#    'ARHGAP25',
#    'C1D',
#    'CNRIP1',
#    'FBXO48',
#    'PLEK',
#    'PNO1',
#    'PPP3R1',
#    'WDR92'],
#   'region_gene_start': np.int64(68041130),
#   'region_gene_end': np.int64(68826833)},
#  '2_68912432_70528066': {'genes': ['AAK1',
#    'ANTXR1',
#    'ANXA4',
#    'ASPRV1',
#    'C2orf42',
#    'FAM136A',
#    'GFPT1',
#    'GKN2',
#    'GMCL1',
#    'MXD1',
#    'NFU1',
#    'PCBP1',
#    'PCYOX1',
#    'SNRNP27',
#    'SNRPG',
#    'TGFA',
#    'TIA1'],
#   'region_gene_start': np.int64(68945232),
#   'region_gene_end': np.int64(70554193)},
#  '2_70528066_72947719': {'genes': ['ADD2',
#    'ANKRD53',
#    'ATP6V1B1',
#    'CLEC4F',
#    'CYP26B1',
#    'DYSF',
#    'EMX1',
#    'EXOC6B',
#    'FIGLA',
#    'MCEE',
#    'MPHOSPH10',
#    'NAGK',
#    'PAIP2B',
#    'SFXN5',
#    'SPR',
#    'TEX261',
#    'TGFA',
#    'VAX2',
#    'ZNF638'],
#   'region_gene_start': np.int64(70447284),
#   'region_gene_end': np.int64(73075619)},
#  '2_72947719_75402960': {'genes': ['ACTG2',
#    'ALMS1',
#    'AUP1',
#    'BOLA3',
#    'C2orf78',
#    'C2orf81',
#    'CCDC142',
#    'CCT7',
#    'DCTN1',
#    'DGUOK',
#    'DOK1',
#    'DQX1',
#    'DUSP11',
#    'EGR4',
#    'FBXO41',
#    'HK2',
#    'HTRA2',
#    'INO80B',
#    'LOXL3',
#    'M1AP',
#    'MOB1A',
#    'MOGS',
#    'MTHFD2',
#    'NAT8',
#    'NOTO',
#    'PCGF1',
#    'POLE4',
#    'PRADC1',
#    'RAB11FIP5',
#    'RTKN',
#    'SEMA4F',
#    'SFXN5',
#    'SLC4A5',
#    'SMYD5',
#    'STAMBP',
#    'TACR1',
#    'TET3',
#    'TLX2',
#    'TPRKB',
#    'TTC31',
#    'WBP1',
#    'WDR54'],
#   'region_gene_start': np.int64(72942036),
#   'region_gene_end': np.int64(75199520)},
#  '2_75402960_76686535': {'genes': ['EVA1A', 'GCFC2'],
#   'region_gene_start': np.int64(75469302),
#   'region_gene_end': np.int64(75710985)},
#  '2_76686535_77852138': {'genes': ['LRRTM4'],
#   'region_gene_start': np.int64(76747719),
#   'region_gene_end': np.int64(77593319)},
#  '2_77852138_79823277': {'genes': ['CTNNA2'],
#   'region_gene_start': np.int64(79185231),
#   'region_gene_end': np.int64(80648861)},
#  '2_79823277_81393717': {'genes': ['CTNNA2', 'LRRTM1'],
#   'region_gene_start': np.int64(79185231),
#   'region_gene_end': np.int64(80648861)},
#  '2_81393717_84913556': {'genes': ['DNAH6', 'SUCLG1', 'TMSB10', 'TRABD2A'],
#   'region_gene_start': np.int64(84423528),
#   'region_gene_end': np.int64(84907008)},
#  '2_84913556_87738988': {'genes': ['ATOH8',
#    'C2orf68',
#    'CAPG',
#    'CD8A',
#    'CD8B',
#    'CHMP3',
#    'ELMOD3',
#    'GGCX',
#    'GNLY',
#    'IMMT',
#    'KCMF1',
#    'KDM3A',
#    'MAT2A',
#    'PLGLB1',
#    'POLR1A',
#    'PTCD3',
#    'REEP1',
#    'RETSAT',
#    'RGPD1',
#    'RMND5A',
#    'RNF103',
#    'RNF181',
#    'SFTPB',
#    'SH2D6',
#    'ST3GAL5',
#    'TCF7L1',
#    'TGOLN2',
#    'TMEM150A',
#    'USP39',
#    'VAMP5',
#    'VAMP8'],
# ...
#   'region_gene_start': np.int64(132120859),
#   'region_gene_end': np.int64(133571940)},
#  '8_133557758_135023362': {'genes': ['ST3GAL1', 'ZFAT'],
#   'region_gene_start': np.int64(133454848),
#   'region_gene_end': np.int64(134713049)},
#  '8_135023362_136511908': {'genes': ['KHDRBS3'],
#   'region_gene_start': np.int64(135457456),
#   'region_gene_end': np.int64(135656722)},
#  '8_136511908_138242587': {'genes': ['FAM135B'],
#   'region_gene_start': np.int64(138130023),
#   'region_gene_end': np.int64(138497261)},
#  '8_138242587_139713400': {'genes': ['COL22A1', 'FAM135B', 'KCNK9'],
#   'region_gene_start': np.int64(138130023),
#   'region_gene_end': np.int64(139704109)},
#  '8_139713400_141963553': {'genes': ['AGO2',
#    'CHRAC1',
#    'DENND3',
#    'GPR20',
#    'PTK2',
#    'PTP4A3',
#    'SLC45A4',
#    'TRAPPC9'],
#   'region_gene_start': np.int64(139727725),
#   'region_gene_end': np.int64(141432454)},
#  '8_141963553_143155464': {'genes': ['ARC',
#    'CYP11B1',
#    'GML',
#    'JRK',
#    'LY6D',
#    'LY6E',
#    'LY6K',
#    'LYNX1',
#    'PSCA',
#    'THEM6',
#    'TSNARE1'],
#   'region_gene_start': np.int64(142212080),
#   'region_gene_end': np.int64(143023832)},
#  '8_143155464_145078481': {'genes': ['ADCK5',
#    'ARHGAP39',
#    'BOP1',
#    'C8orf33',
#    'C8orf82',
#    'CCDC166',
#    'COMMD5',
#    'CPSF1',
#    'CYC1',
#    'CYHR1',
#    'DGAT1',
#    'EEF1D',
#    'EPPK1',
#    'EXOSC4',
#    'FAM83H',
#    'FBXL6',
#    'FOXH1',
#    'GLI4',
#    'GPAA1',
#    'GPIHBP1',
#    'GPT',
#    'GRINA',
#    'GSDMD',
#    'HGH1',
#    'HSF1',
#    'KIFC2',
#    'LRRC14',
#    'LRRC24',
#    'LY6H',
#    'MAF1',
#    'MAFA',
#    'MAPK15',
#    'MFSD3',
#    'MROH1',
#    'MROH6',
#    'NAPRT',
#    'NRBP2',
#    'OPLAH',
#    'PARP10',
#    'PLEC',
#    'PPP1R16A',
#    'PUF60',
#    'RECQL4',
#    'RHPN1',
#    'SCRIB',
#    'SCRT1',
#    'SCX',
#    'SHARPIN',
#    'SLC39A4',
#    'SLC52A2',
#    'SPATC1',
#    'TIGD5',
#    'TMEM249',
#    'TONSL',
#    'TOP1MT',
#    'TSTA3',
#    'VPS28',
#    'ZC3H3',
#    'ZFP41',
#    'ZNF16',
#    'ZNF250',
#    'ZNF251',
#    'ZNF34',
#    'ZNF517',
#    'ZNF623',
#    'ZNF696',
#    'ZNF7',
#    'ZNF707'],
#   'region_gene_start': np.int64(143157914),
#   'region_gene_end': np.int64(145066685)},
#  '9_10023_1079707': {'genes': ['CBWD1',
#    'DMRT1',
#    'DMRT2',
#    'DMRT3',
#    'DOCK8',
#    'FOXD4',
#    'KANK1'],
#   'region_gene_start': np.int64(116231),
#   'region_gene_end': np.int64(1057552)},
#  '9_1079707_1916877': {'genes': [],
#   'region_gene_start': None,
#   'region_gene_end': None},
#  '9_1916877_3190064': {'genes': ['KCNV2', 'SMARCA2', 'VLDLR'],
#   'region_gene_start': np.int64(1980290),
#   'region_gene_end': np.int64(2730037)},
#  '9_3190064_4495328': {'genes': ['GLIS3', 'RFX3', 'SLC1A1'],
#   'region_gene_start': np.int64(3218297),
#   'region_gene_end': np.int64(4587469)},
#  '9_4495328_4884926': {'genes': ['AK3',
#    'CDC37L1',
#    'RCL1',
#    'SLC1A1',
#    'SPATA6L'],
#   'region_gene_start': np.int64(4490468),
#   'region_gene_end': np.int64(4885917)},
#  '9_4884926_6557589': {'genes': ['CD274',
#    'ERMP1',
#    'GLDC',
#    'IL33',
#    'INSL6',
#    'JAK2',
#    'KIAA2026',
#    'MLANA',
#    'PDCD1LG2',
#    'PLGRKT',
#    'RANBP6',
#    'RCL1',
#    'RIC1',
#    'RLN1',
#    'RLN2',
#    'UHRF2'],
#   'region_gene_start': np.int64(4792944),
#   'region_gene_end': np.int64(6645729)},
#  '9_6557589_7154923': {'genes': ['GLDC', 'KDM4C'],
#   'region_gene_start': np.int64(6532467),
#   'region_gene_end': np.int64(7175648)},
#  '9_7154923_8456299': {'genes': ['KDM4C', 'PTPRD'],
#   'region_gene_start': np.int64(6720863),
#   'region_gene_end': np.int64(10612723)},
#  '9_8456299_9166403': {'genes': ['PTPRD'],
#   'region_gene_start': np.int64(8314246),
#   'region_gene_end': np.int64(10612723)},
#  '9_9166403_10879253': {'genes': ['PTPRD'],
#   'region_gene_start': np.int64(8314246),
#   'region_gene_end': np.int64(10612723)},
#  '9_10879253_12276489': {'genes': [],
#   'region_gene_start': None,
#   'region_gene_end': None},
#  '9_12276489_14836365': {'genes': ['CER1',
#    'FREM1',
#    'LURAP1L',
#    'MPDZ',
#    'NFIB',
#    'TYRP1',
#    'ZDHHC21'],
#   'region_gene_start': np.int64(12685439),
#   'region_gene_end': np.int64(14910995)},
#  '9_14836365_16659657': {'genes': ['BNC2',
#    'C9orf92',
#    'CCDC171',
#    'FREM1',
#    'PSIP1',
#    'SNAPC3',
#    'TTC39B'],
#   'region_gene_start': np.int64(14734666),
#   'region_gene_end': np.int64(16870843)},
#  '9_16659657_18661053': {'genes': ['ADAMTSL1', 'BNC2', 'CNTLN', 'SH3GL2'],
#   'region_gene_start': np.int64(16409503),
#   'region_gene_end': np.int64(18910950)},
#  '9_18661053_20463536': {'genes': ['ACER2',
#    'ADAMTSL1',
#    'DENND4C',
#    'HAUS6',
#    'MLLT3',
#    'PLIN2',
#    'RRAGA',
#    'SLC24A2'],
#   'region_gene_start': np.int64(17906563),
#   'region_gene_end': np.int64(20622518)},
#  '9_20463536_22206560': {'genes': ['CDKN2A',
#    'CDKN2B',
#    'FOCAD',
#    'IFNA13',
#    'IFNA2',
#    'IFNA6',
#    'IFNE',
#    'IFNW1',
#    'KLHL9',
#    'MLLT3',
#    'MTAP'],
#   'region_gene_start': np.int64(20341669),
#   'region_gene_end': np.int64(22009305)},
#  '9_22206560_24158520': {'genes': ['DMRTA1', 'ELAVL2'],
#   'region_gene_start': np.int64(22446824),
#   'region_gene_end': np.int64(23826337)},
#  '9_24158520_25330812': {'genes': ['IZUMO3'],
#   'region_gene_start': np.int64(24542952),
#   'region_gene_end': np.int64(24545946)},
#  '9_25330812_26111759': {'genes': ['TUSC1'],
#   'region_gene_start': np.int64(25676389),
#   'region_gene_end': np.int64(25678440)},
#  '9_26111759_28224285': {'genes': ['C9orf72',
#    'CAAP1',
#    'EQTN',
#    'IFNK',
#    'IFT74',
#    'LINGO2',
#    'LRRC19',
#    'MOB3B',
#    'PLAA',
#    'TEK'],
#   'region_gene_start': np.int64(26840685),
#   'region_gene_end': np.int64(28670286)},
#  '9_28224285_28811586': {'genes': ['LINGO2'],
#   'region_gene_start': np.int64(27948078),
#   'region_gene_end': np.int64(28670286)},
#  '9_28811586_30387394': {'genes': [],
#   'region_gene_start': None,
#   'region_gene_end': None},
#  '9_30387394_31310385': {'genes': [],
#   'region_gene_start': None,
#   'region_gene_end': None},
#  '9_31310385_32019370': {'genes': [],
#   'region_gene_start': None,
#   'region_gene_end': None},
#  '9_32019370_33578336': {'genes': ['ACO1',
#    'ANKRD18B',
#    'APTX',
#    'AQP3',
#    'AQP7',
#    'B4GALT1',
#    'BAG1',
#    'CHMP5',
#    'DDX58',
#    'DNAJA1',
#    'NDUFB6',
#    'NFX1',
#    'NOL6',
#    'SMU1',
#    'SPINK4',
#    'TAF1L',
#    'TMEM215',
#    'TOPORS'],
#   'region_gene_start': np.int64(32384603),
#   'region_gene_end': np.int64(33573009)},
#  '9_33578336_34642246': {'genes': ['ARID3C',
#    'C9orf24',
#    'CNTFR',
#    'DCAF12',
#    'DCTN3',
#    'DNAI1',
#    'ENHO',
#    'FAM219A',
#    'GALT',
#    'KIF24',
#    'NUDT2',
#    'PRSS3',
#    'RPP25L',
#    'SIGMAR1',
#    'UBAP1',
#    'UBAP2',
#    'UBE2R2'],
#   'region_gene_start': np.int64(33750466),
#   'region_gene_end': np.int64(34651035)},
#  '9_34642246_36743286': {'genes': ['ARHGEF39',
#    'C9orf131',
#    'CA9',
#    'CCDC107',
#    'CCL19',
#    'CCL27',
#    'CD72',
#    'CLTA',
#    'CREB3',
#    'DNAJB5',
#    'FAM166B',
#    'FAM214B',
#    'FAM221B',
#    'FANCG',
#    'GALT',
#    'GBA2',
#    'GLIPR2',
#    'GNE',
#    'HINT2',
#    'HRCT1',
#    'IL11RA',
#    'MELK',
#    'MSMP',
#    'NPR2',
#    'PIGO',
#    'RECK',
#    'RGP1',
#    'RNF38',
#    'RUSC2',
#    'SPAG8',
#    'STOML2',
#    'TESK1',
#    'TLN1',
#    'TMEM8B',
#    'TPM2',
#    'UNC13B',
#    'VCP'],
#   'region_gene_start': np.int64(34638133),
#   'region_gene_end': np.int64(36677683)},
#  '9_36743286_38641602': {'genes': ['ALDH1B1',
#    'ANKRD18A',
#    'DCAF10',
#    'EXOSC3',
#    'FBXO10',
#    'FRMPD1',
#    'GRHPR',
#    'IGFBPL1',
#    'PAX5',
#    'POLR1E',
#    'SHB',
#    'SLC25A51',
#    'TOMM5',
#    'TRMT10B',
#    'ZBTB5',
#    'ZCCHC7'],
#   'region_gene_start': np.int64(36833269),
#   'region_gene_end': np.int64(38620596)},
#  '9_38641602_39393282': {'genes': ['CNTNAP3'],
#   'region_gene_start': np.int64(39072767),
#   'region_gene_end': np.int64(39288315)},
#  '9_39393282_69897795': {'genes': ['ANKRD20A1',
#    'APBA1',
#    'C9orf135',
#    'CBWD3',
#    'CBWD5',
#    'CNTNAP3B',
#    'FAM122A',
#    'FAM189A2',
#    'FAM27C',
#    'FOXD4L3',
#    'FOXD4L5',
#    'FOXD4L6',
#    'FXN',
#    'PGM5',
#    'PIP5K1B',
#    'PTAR1',
#    'TJP2',
#    'ZNF658'],
#   'region_gene_start': np.int64(41126430),
#   'region_gene_end': np.int64(69906227)},
#  '9_69897795_70138839': {'genes': ['C9orf135', 'MAMDC2'],
#   'region_gene_start': np.int64(69820817),
#   'region_gene_end': np.int64(70226972)},
#  '9_70138839_71638124': {'genes': ['KLF9', 'MAMDC2', 'SMC5', 'TRPM3'],
#   'region_gene_start': np.int64(70043848),
#   'region_gene_end': np.int64(71446904)},
#  '9_71638124_73589030': {'genes': ['ABHD17B',
#    'ALDH1A1',
#    'ANXA1',
#    'C9orf57',
#    'C9orf85',
#    'GDA',
#    'TMC1',
#    'ZFAND5'],
#   'region_gene_start': np.int64(71862452),
#   'region_gene_end': np.int64(73170393)},
#  '9_73589030_74358165': {'genes': [],
#   'region_gene_start': None,
#   'region_gene_end': None},
#  '9_74358165_76285267': {'genes': ['C9orf40',
#    'NMRK1',
#    'OSTF1',
#    'PCSK5',
#    'RORB',
#    'TRPM6'],
#   'region_gene_start': np.int64(74497335),
#   'region_gene_end': np.int64(76362975)},
#  '9_76285267_76856292': {'genes': ['GCNT1', 'PCSK5', 'PRUNE2', 'RFK'],
#   'region_gene_start': np.int64(75890644),
#   'region_gene_end': np.int64(76906114)},
#  '9_76856292_78464139': {'genes': ['CEP78',
#    'GNA14',
#    'GNAQ',
#    'PRUNE2',
#    'PSAT1',
#    'VPS13A'],
#   'region_gene_start': np.int64(76611376),
#   'region_gene_end': np.int64(78330093)},
#  '9_78464139_79976013': {'genes': ['TLE4'],
#   'region_gene_start': np.int64(79571773),
#   'region_gene_end': np.int64(79726882)},
#  '9_79976013_81596318': {'genes': ['TLE1'],
#   'region_gene_start': np.int64(81583683),
#   'region_gene_end': np.int64(81689547)},
#  '9_81596318_82825886': {'genes': ['TLE1'],
#   'region_gene_start': np.int64(81583683),
#   'region_gene_end': np.int64(81689547)},
#  '9_82825886_84323281': {'genes': ['C9orf64',
#    'FRMD3',
#    'GKAP1',
#    'HNRNPK',
#    'IDNK',
#    'KIF27',
#    'RASEF',
#    'RMI1',
#    'SLC28A3',
#    'UBQLN1'],
#   'region_gene_start': np.int64(82979590),
#   'region_gene_end': np.int64(84340758)},
#  '9_84323281_85494418': {'genes': ['NTRK2', 'SLC28A3'],
#   'region_gene_start': np.int64(84275457),
#   'region_gene_end': np.int64(85027070)},
#  '9_85494418_85975502': {'genes': ['AGTPBP1', 'NAA35'],
#   'region_gene_start': np.int64(85546539),
#   'region_gene_end': np.int64(86025462)},
#  '9_85975502_87521331': {'genes': ['C9orf153',
#    'DAPK1',
#    'GAS1',
#    'GOLM1',
#    'ISCA1',
#    'NAA35'],
#   'region_gene_start': np.int64(85941146),
#   'region_gene_end': np.int64(87708634)},
#  '9_87521331_89827251': {'genes': ['CDK20',
#    'CKS2',
#    'CTSL',
#    'DAPK1',
#    'GADD45G',
#    'NXNL2',
#    'S1PR3',
#    'SECISBP2',
#    'SEMA4D',
#    'SHC3',
#    'SPIN1'],
#   'region_gene_start': np.int64(87497228),
#   'region_gene_end': np.int64(89606555)},
#  '9_89827251_91404921': {'genes': ['AUH', 'DIRAS2', 'SYK'],
#   'region_gene_start': np.int64(90609832),
#   'region_gene_end': np.int64(91361918)},
#  '9_91404921_93909416': {'genes': ['ASPN',
#    'BICD2',
#    'C9orf129',
#    'CENPP',
#    'ECM2',
#    'FAM120A',
#    'FAM120AOS',
#    'FGD3',
#    'IPPK',
#    'NFIL3',
#    'NINJ1',
#    'NOL8',
#    'OGN',
#    'OMD',
#    'PHF2',
#    'ROR2',
#    'SPTLC1',
#    'SUSD3',
#    'WNK2',
#    'ZNF484'],
#   'region_gene_start': np.int64(91409045),
#   'region_gene_end': np.int64(93679587)},
#  '9_93909416_96159758': {'genes': ['ERCC6L2',
#    'FANCC',
#    'FBP1',
#    'FBP2',
#    'NUTM2F',
#    'PTCH1',
#    'PTPDC1',
#    'ZNF169'],
#   'region_gene_start': np.int64(94030794),
#   'region_gene_end': np.int64(96121154)},
#  '9_96159758_98830577': {'genes': ['ANKS6',
#    'ANP32B',
#    'CCDC180',
#    'CDC14B',
#    'CORO2A',
#    'CTSV',
#    'FOXE1',
#    'GABBR2',
#    'GALNT12',
#    'HABP4',
#    'HEMGN',
#    'HSD17B3',
#    'NANS',
#    'NCBP1',
#    'NUTM2G',
#    'SLC35D2',
#    'TBC1D2',
#    'TDRD7',
#    'TMOD1',
#    'TRIM14',
#    'TSTD2',
#    'XPA',
#    'ZNF367',
#    'ZNF510',
#    'ZNF782'],
#   'region_gene_start': np.int64(96235306),
#   'region_gene_end': np.int64(98850081)},
#  '9_98830577_101862155': {'genes': ['ALDOB',
#    'ALG2',
#    'BAAT',
#    'COL15A1',
#    'ERP44',
#    'GALNT12',
#    'GRIN3A',
#    'INVS',
#    'MSANTD3',
#    'NR4A3',
#    'PPP3R2',
#    'RNF20',
#    'SEC61B',
#    'STX17',
#    'TEX10',
#    'TGFBR1',
#    'TMEFF1',
#    'ZNF189'],
#   'region_gene_start': np.int64(98807670),
#   'region_gene_end': np.int64(101738647)},
#  '9_101862155_103205694': {'genes': [],
#   'region_gene_start': None,
#   'region_gene_end': None},
#  '9_103205694_104819468': {'genes': ['ABCA1',
#    'NIPSNAP3A',
#    'NIPSNAP3B',
#    'OR13C2',
#    'OR13C3',
#    'OR13C4',
#    'OR13C5',
#    'SMC2'],
#   'region_gene_start': np.int64(104094260),
#   'region_gene_end': np.int64(104928155)},
#  '9_104819468_106536473': {'genes': ['ABCA1',
#    'FKTN',
#    'FSD1L',
#    'SLC44A1',
#    'TAL2',
#    'TMEM38B'],
#   'region_gene_start': np.int64(104781006),
#   'region_gene_end': np.int64(105776629)},
#  '9_106536473_107932781': {'genes': ['KLF4', 'RAD23B', 'ZNF462'],
#   'region_gene_start': np.int64(106863166),
#   'region_gene_end': np.int64(107490482)},
#  '9_107932781_110015744': {'genes': ['CTNNAL1',
#    'EPB41L4B',
#    'FRRS1L',
#    'PTPN3',
#    'TMEM245'],
#   'region_gene_start': np.int64(108942569),
#   'region_gene_end': np.int64(109498313)},
#  '9_110015744_112068802': {'genes': ['C9orf152',
#    'DNAJC25',
#    'GNG10',
#    'LPAR1',
#    'MUSK',
#    'PTGR1',
#    'SUSD1',
#    'SVEP1',
#    'TXN',
#    'TXNDC8',
#    'UGCG',
#    'ZNF483'],
#   'region_gene_start': np.int64(110190048),
#   'region_gene_end': np.int64(112175297)},
#  '9_112068802_112930865': {'genes': ['HSDL2',
#    'INIP',
#    'KIAA1958',
#    'PTBP3',
#    'SLC46A2',
#    'SNX30',
#    'SUSD1'],
#   'region_gene_start': np.int64(112040783),
#   'region_gene_end': np.int64(112890876)},
#  '9_112930865_114257521': {'genes': ['ALAD',
#    'AMBP',
#    'BSPRY',
#    'C9orf43',
#    'CDC26',
#    'COL27A1',
#    'FKBP15',
#    'HDHD3',
#    'KIF12',
#    'POLE3',
#    'PRPF4',
#    'RGS3',
#    'RNF183',
#    'SLC31A1',
#    'SLC31A2',
#    'WDR31',
#    'ZFP37',
#    'ZNF618'],
#   'region_gene_start': np.int64(113038380),
#   'region_gene_end': np.int64(114312511)},
#  '9_114257521_115159681': {'genes': ['AKNA',
#    'ATP6V1G1',
#    'COL27A1',
#    'TNC',
#    'TNFSF15',
#    'TNFSF8'],
#   'region_gene_start': np.int64(114155537),
#   'region_gene_end': np.int64(115118257)},
#  '9_115159681_118559259': {'genes': ['ASTN2', 'PAPPA', 'TLR4', 'TRIM32'],
#   'region_gene_start': np.int64(116153791),
#   'region_gene_end': np.int64(117724735)},
#  '9_118559259_119498019': {'genes': ['BRINP1'],
#   'region_gene_start': np.int64(119153458),
#   'region_gene_end': np.int64(119369435)},
#  '9_119498019_122109043': {'genes': ['C5',
#    'CDK5RAP2',
#    'CNTRL',
#    'DAB2IP',
#    'FBXW2',
#    'GSN',
#    'MEGF9',
#    'PHF19',
#    'PSMD5',
#    'RAB14',
#    'STOM',
#    'TRAF1',
#    'TTLL11'],
#   'region_gene_start': np.int64(120388869),
#   'region_gene_end': np.int64(122093606)},
#  '9_122109043_124209608': {'genes': ['CRB2',
#    'DENND1A',
#    'GPR21',
#    'LHX2',
#    'LHX6',
#    'MORN5',
#    'MRRF',
#    'NDUFA8',
#    'OR1L6',
#    'OR1L8',
#    'OR1N2',
#    'PDCL',
#    'PTGS1',
#    'RABGAP1',
#    'RBM18',
#    'RC3H2',
#    'STRBP',
#    'ZBTB26',
#    'ZBTB6'],
#   'region_gene_start': np.int64(122144058),
#   'region_gene_end': np.int64(124033301)},
#  '9_124209608_126297386': {'genes': ['ARPC5L',
#    'GAPVD1',
#    'GOLGA1',
#    'HSPA5',
#    'MAPKAP1',
#    'NEK6',
#    'NR5A1',
#    'NR6A1',
#    'OLFML2A',
#    'PBX3',
#    'PPP6C',
#    'PSMB7',
#    'RABEPK',
#    'SCAI'],
#   'region_gene_start': np.int64(124257606),
#   'region_gene_end': np.int64(125967377)},
#  '9_126297386_127293231': {'genes': ['ANGPTL2',
#    'GARNL3',
#    'LMX1B',
#    'MVB12B',
#    'RALGPS1',
#    'ZBTB34',
#    'ZBTB43'],
#   'region_gene_start': np.int64(126326829),
#   'region_gene_end': np.int64(127393660)},
#  '9_127293231_129403191': {'genes': ['AK1',
#    'AL162426.1',
#    'C9orf16',
#    'CDK9',
#    'CERCAM',
#    'CIZ1',
#    'COQ4',
#    'CRAT',
#    'DNM1',
#    'DOLK',
#    'DOLPP1',
#    'DPM2',
#    'ENDOG',
#    'ENG',
#    'FAM102A',
#    'FPGS',
#    'GARNL3',
#    'GLE1',
#    'GOLGA2',
#    'IER5L',
#    'LRRC8A',
#    'LRSAM1',
#    'NAIF1',
#    'NUP188',
#    'ODF2',
#    'PHYHD1',
#    'PIP5KL1',
#    'PKN3',
#    'PTGES2',
#    'PTRH1',
#    'SET',
#    'SH2D3C',
#    'SH3GLB2',
#    'SLC25A25',
#    'SLC27A4',
#    'SLC2A8',
#    'SPTAN1',
#    'ST6GALNAC4',
#    'ST6GALNAC6',
#    'STXBP1',
#    'SWI5',
#    'TBC1D13',
#    'TOR2A',
#    'TRUB2',
#    'TTC16',
#    'URM1',
#    'WDR34',
#    'ZDHHC12',
#    'ZER1',
#    'ZNF79'],
#   'region_gene_start': np.int64(127224265),
#   'region_gene_end': np.int64(129178261)},
#  ...}

# %%
len(region_gene_map)
# Out:
# 1700

# %%
valid_count = sum(
    1 for v in region_gene_map.values()
    if v['region_gene_start'] is not None and v['region_gene_end'] is not None
)

print(f"effective region number: {valid_count}")
# Out:
# effective region number: 1587

# %%
valid_region_gene_map = {
    k: v for k, v in region_gene_map.items()
    if v['region_gene_start'] is not None and v['region_gene_end'] is not None
}

# %%
len(valid_region_gene_map)
# Out:
# 1587

# %%
# 拷贝有效数据并扩展起止位置 ±1Mb
expanded_region_gene_map = {
    k: {
        'genes': v['genes'],
        'region_gene_start': max(v['region_gene_start'] - 1_000_000, 1),
        'region_gene_end': v['region_gene_end'] + 1_000_000
    }
    for k, v in valid_region_gene_map.items()
}

# %%
import json

with open('region_gene_map.json', 'w', encoding='utf-8') as f:
    json.dump(region_gene_map, f, indent=2, ensure_ascii=False, default=int)

# %%
with open('valid_region_gene_map.json', 'w', encoding='utf-8') as f:
    json.dump(valid_region_gene_map, f, indent=2, ensure_ascii=False, default=int)

# %%
with open('expanded_region_gene_map.json', 'w', encoding='utf-8') as f:
    json.dump(expanded_region_gene_map, f, indent=2, ensure_ascii=False, default=int)

# %% [markdown]
# # Save region.tsv for extracting snps

# %%
import json
import pandas as pd

# 加载 JSON
with open("valid_region_gene_map.json", "r") as f:
    region_map = json.load(f)

# 构造 DataFrame
df = pd.DataFrame([
    {
        "region_id": region_id,
        "region_gene_start": data["region_gene_start"],
        "region_gene_end": data["region_gene_end"]
    }
    for region_id, data in region_map.items()
])

# 提取染色体号
df["chrom"] = df["region_id"].str.extract(r'^(\d+)_').astype(int)
df["start"] = df["region_gene_start"]
df["end"] = df["region_gene_end"]

# 按顺序输出为 tsv
df[["chrom", "start", "end", "region_id"]].to_csv("valid_regions.tsv", sep="\t", header=False, index=False)

# %% [markdown]
# Use tabix and plink find snps within the expanded_region

# %% [markdown]
# What to do next:
#
# 1; get snps information of all the samples.
# 3; Find the genes within the given LD region
# 3; redefine the region(first gene-1mb, last gene+1mb)
# 4; find the snps within the region
# 5; do tensor regression
# 6; 5fold and get the Rsquare

# %% [markdown]
# the WGS VCF files I used for training is under "/projects/YangLabData/rparrish/ROSMAP_WGS/genotype/"  with file names like CHR${chr}_ROSMAP_WGS_b38_lifted_TIGAR.vcf.gz .

# %%
# Out:
# 发生错误：Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %% [markdown]
# the WGS VCF files I used for training is under "/projects/YangLabData/rparrish/ROSMAP_WGS/genotype/"  with file names like CHR${chr}_ROSMAP_WGS_b38_lifted_TIGAR.vcf.gz .

# %% [markdown]
# the WGS VCF files I used for training is under "/projects/YangLabData/rparrish/ROSMAP_WGS/genotype/"  with file names like CHR${chr}_ROSMAP_WGS_b38_lifted_TIGAR.vcf.gz .
